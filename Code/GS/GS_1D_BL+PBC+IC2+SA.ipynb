# %% [markdown]
# # PINN Solution of the Gray Scott PDEs
#
# This PyTorch code demonstrates the application of physically-informed neural networks (PINN) in the solution of a well-known Gray Scott PDEs with periodic boundary condition
# \begin{aligned}
#   &u_t = \epsilon_1\Delta u + b(1 - u) - uv^2, \quad (t, x) \in [0, T]\times[-L, L]\\
#   &v_t = \epsilon_2\Delta v -dv + uv^2, \\
#   &u(0, x) = u_0(x), \quad v(0, x) = v_0(x), \quad \forall x \in [-L, L] \\
#   &u(t, -L) = u(t, L), \quad v(t, -L) = v(t, L), \quad \forall t \in [0, T]
# \end{aligned}
# where $\epsilon_1, \epsilon_2, b, d > 0$ are some parameters, and $[x_{\min}, x_{\max}]$ covers one full period.
#
# See [this link](https://www.chebfun.org/examples/pde/GrayScott.html) for a description

# %% [markdown]
# ## Libraries and Dependencies

# %%
from itertools import chain
from collections import OrderedDict
import time
import numpy as np
import scipy as sp
import scipy.io
from scipy.interpolate import griddata
from pyDOE import lhs
import torch
import torch.optim
import torch.optim.lr_scheduler as lr_scheduler
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.gridspec as gridspec
np.random.seed(1234)

# %%
# MPS or CUDA or CPU
if torch.backends.mps.is_available():
    device = torch.device('mps')
elif torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
#
print(f"Working on {device}")
# Out:
# Working on mps

# %%
epsilon1 = 1
epsilon2 = 1e-2
b = 2e-2
d = 8.62e-2
L = 50.0
xlo = -L
xhi = L
period = xhi - xlo
tlo = 0.0
thi = 20.0
pi_ten = torch.tensor(np.pi).float().to(device)
L_ten = torch.tensor(L).float().to(device)
u0 = lambda x: 1.0 - 0.5 * np.power(np.sin(np.pi * (x - L)/(2.0 * L)), 4.0)
u0_ten = lambda x: 1.0 - 0.5 * torch.pow(torch.sin(pi_ten * (x - L_ten)/(2.0 * L_ten)), 4.0)
v0 = lambda x: 0.25 * np.power(np.sin(np.pi * (x - L)/(2.0 * L)), 4.0)
v0_ten = lambda x: 0.25 * torch.pow(torch.sin(pi_ten * (x - L_ten)/(2.0 * L_ten)), 4.0)

# %% [markdown]
# ## Physics-informed Neural Networks

# %%
# the deep neural network
class DNN(torch.nn.Module):
    def __init__(self, layers):
        super(DNN, self).__init__()
        # parameters
        self.depth = len(layers) - 1
        # set up layer order dict
        self.activation = torch.nn.Tanh
        layer_list = list()
        for i in range(self.depth - 1): 
            layer_list.append(
                ('layer_%d' % i, torch.nn.Linear(layers[i], layers[i+1]))
            )
            layer_list.append(('activation_%d' % i, self.activation()))
            
        layer_list.append(
            ('layer_%d' % (self.depth - 1), torch.nn.Linear(layers[-2], layers[-1]))
        )
        layerDict = OrderedDict(layer_list)
        # deploy layers
        self.layers = torch.nn.Sequential(layerDict)
        self.layers[0].weight = torch.load('initial_weights_PBC.pt')
    def forward(self, x):
        out = self.layers(x)
        return out

# %%
class PhysicsInformedNN():
    def __init__(self, period, m, X_PDE, layers, epsilon1, epsilon2,b,d):
        # Prepare the periodic layer
        m_vec = np.expand_dims(np.arange(1, m + 1), axis = 0)
        self.ms = torch.tensor(2.0 * np.pi/period * m_vec).float().to(device)
        # PDE data, gradients will be computed on these points so requires_grad = True
        self.t_PDE = torch.tensor(X_PDE[:, 0:1], requires_grad=True).float().to(device)
        self.x_PDE = torch.tensor(X_PDE[:, 1:2], requires_grad=True).float().to(device)
        N_PDE = X_PDE.shape[0]
        self.LW_uPDE = torch.nn.ParameterList([torch.nn.Parameter(torch.ones(N_PDE, 1).float(), requires_grad=True).to(device)])
        self.LW_vPDE = torch.nn.ParameterList([torch.nn.Parameter(torch.ones(N_PDE, 1).float(), requires_grad=True).to(device)])

       
       
    
        layers[0] = int(2 * m + 2)
        self.layers = layers
        # equation related parameters
        self.epsilon1 = torch.tensor(epsilon1).float().to(device)
        self.epsilon2 = torch.tensor(epsilon2).float().to(device)
        self.b = b
        self.d = d
    
        # deep neural networks
        self.dnn = DNN(layers).to(device)    
        # prepare the optimizer
        self.optimizer_Adam = torch.optim.Adam(self.dnn.parameters(), lr = 1e-3)
        self.optimizer_LW_uPDE = torch.optim.Adam(self.LW_uPDE.parameters(), lr = 5e-3)
        self.optimizer_LW_vPDE = torch.optim.Adam(self.LW_vPDE.parameters(), lr = 5e-3)
    
        # add a learning rate scheduler
        self.optimizer_LBFGS = torch.optim.LBFGS(
            self.dnn.parameters(), 
            lr=1.0, 
            max_iter=10000, 
            max_eval=5000, 
            history_size=50,
            tolerance_grad=1e-7, 
            tolerance_change=1.0 * np.finfo(float).eps,
            line_search_fn="strong_wolfe"       # can be "strong_wolfe"
        )        
       
       
        self.iter = 0
    # update alpha
    
    def NN_reset_iter(self):
        self.iter = 0
    # evaluater neural network
    # with transformation to include the initial condition
    def NN_eval(self, t, x):  
        x_trans = torch.matmul(x, self.ms)
        NN = self.dnn(torch.cat([t, torch.ones_like(x), torch.cos(x_trans), torch.sin(x_trans)], dim = 1))
        uNN = NN[:, 0][:, None]
        vNN = NN[:, 1][:, None]
        u0_torch = u0_ten(x)
        v0_torch = v0_ten(x)
        unew = u0_torch*torch.exp(-0.1*t) + t * uNN
        vnew = v0_torch*torch.exp(-0.1*t) + t * vNN
        return unew,vnew
    # compute the PDE
    def pde_eval(self, t, x):
        """ The pytorch autograd version of calculating residual """
        u, v = self.NN_eval(t, x)
        # compute the derivatives for u
        u_t  = torch.autograd.grad(u,   t, grad_outputs = torch.ones_like(u), retain_graph = True, create_graph=True)[0]
        u_x  = torch.autograd.grad(u,   x, grad_outputs = torch.ones_like(u), retain_graph = True, create_graph=True)[0]
        u_xx = torch.autograd.grad(u_x, x, grad_outputs = torch.ones_like(u), retain_graph = True, create_graph=True)[0]
        v_t = torch.autograd.grad(v, t, grad_outputs = torch.ones_like(v), retain_graph = True, create_graph=True)[0]
        v_x = torch.autograd.grad(v, x, grad_outputs = torch.ones_like(v), retain_graph = True, create_graph=True)[0]
        v_xx = torch.autograd.grad(v_x, x, grad_outputs = torch.ones_like(v), retain_graph = True, create_graph=True)[0]
        Eq1 = u_t - self.epsilon1 * u_xx - self.b * (1.0 - u) + u * torch.pow(v, 2.0)
        Eq2 = v_t - self.epsilon2 * v_xx + self.d * v - u * torch.pow(v, 2.0)
        return Eq1, Eq2
    # compute the total loss for the second-order optimizer
    def loss_func(self):
        # reset the gradient
        self.optimizer_LBFGS.zero_grad()
        # compute PDE loss
        pde1_pred, pde2_pred = self.pde_eval(self.t_PDE, self.x_PDE)
        loss_PDE = torch.mean((self.LW_uPDE[0]*pde1_pred )** 2) + torch.mean((self.LW_vPDE[0]*pde2_pred )** 2)   
         
        # compute the total loss, it can be weighted
        loss = loss_PDE
        # backward propagation
        loss.backward()
        # increase the iteration counter
        self.iter += 1
        # output
        # output the progress
        if self.iter % 1000 == 0:
            print('Iter %5d, Total: %10.4e, PDE: %10.4e' % (self.iter, loss.item(), loss_PDE.item()))
        return loss
    #
    def train(self, nIter):
        # start the training with Adam first
        self.dnn.train()
        print('Starting with Adam')
        for epoch in range(nIter):
           
                # compute PDE loss
            pde1_pred, pde2_pred = self.pde_eval(self.t_PDE, self.x_PDE)
            loss_PDE = torch.mean((self.LW_uPDE[0]*pde1_pred )** 2) + torch.mean((self.LW_vPDE[0]*pde2_pred )** 2)   
         
                # compute the total loss, it can be weighted
            loss = loss_PDE
                # Backward and optimize
            
            self.optimizer_Adam.zero_grad()
            self.optimizer_LW_uPDE.zero_grad()
            self.optimizer_LW_vPDE.zero_grad()
            
            loss.backward()
            self.optimizer_Adam.step() 
            
           
            
            self.LW_uPDE[0].grad.data = -self.LW_uPDE[0].grad.data
            
           
            self.LW_vPDE[0].grad.data = -self.LW_vPDE[0].grad.data
            
           
            self.optimizer_LW_uPDE.step()
            
        
            self.optimizer_LW_vPDE.step()
                # output the progress
            if (epoch + 1) % 1000 == 0:
                print('Iter %5d, Total: %10.4e' % (epoch + 1, loss.item()))
                print('PDE: %10.4e' % (loss_PDE.item()))
                print('For uPDE, min uLW: %10.4e, max uLW: %10.4e' %(torch.min(self.LW_uPDE[0]).item(), torch.max(self.LW_uPDE[0]).item()))
                
                print('For vPDE, min vLW: %10.4e, max vLW: %10.4e' %(torch.min(self.LW_vPDE[0]).item(), torch.max(self.LW_vPDE[0]).item()))
                
                # change the learning rate
                
       # self.optimizer_LBFGS.step(self.loss_func) 
        print('Starting with L-BFGS')
        
        self.optimizer_LBFGS.step(self.loss_func)      
        
    def predict(self, X):
        t = torch.tensor(X[:, 0:1], requires_grad=True).float().to(device)
        x = torch.tensor(X[:, 1:2], requires_grad=True).float().to(device)
        self.dnn.eval()
        u, v = self.NN_eval(t, x)
        u = u.detach().cpu().numpy()
        v = v.detach().cpu().numpy()
        return u,v


## Configurations

# %% [markdown]
# ## Training

# %%
layers = [2, 32, 32, 32, 32, 32, 32, 32, 2]
m = 16
ptsIC=np.load('ptsIC.npy')
ptsBC=np.load('ptsBC.npy')
ptsPDE=np.load('random_data.npy')
ptsPDE = np.vstack((ptsIC,ptsPDE))
ptsPDE = np.vstack((ptsBC,ptsPDE))

model = PhysicsInformedNN(period,m,ptsPDE,layers, epsilon1, epsilon2,b,d)
model.train(50000)
# Out:
# Starting with Adam
# Iter  1000, Total: 7.5944e-06
# PDE: 7.5944e-06
# For uPDE, min uLW: 1.0457e+00, max uLW: 2.6520e+00
# For vPDE, min vLW: 1.0365e+00, max vLW: 3.8323e+00
# Iter  2000, Total: 2.4185e-06
# PDE: 2.4185e-06
# For uPDE, min uLW: 1.0463e+00, max uLW: 2.6532e+00
# For vPDE, min vLW: 1.0366e+00, max vLW: 4.0507e+00
# Iter  3000, Total: 1.2070e-06
# PDE: 1.2070e-06
# For uPDE, min uLW: 1.0464e+00, max uLW: 2.6533e+00
# For vPDE, min vLW: 1.0366e+00, max vLW: 4.1536e+00
# Iter  4000, Total: 6.9282e-07
# PDE: 6.9282e-07
# For uPDE, min uLW: 1.0465e+00, max uLW: 2.6557e+00
# For vPDE, min vLW: 1.0368e+00, max vLW: 4.2256e+00
# Iter  5000, Total: 3.9423e-07
# PDE: 3.9423e-07
# For uPDE, min uLW: 1.0465e+00, max uLW: 2.6633e+00
# For vPDE, min vLW: 1.0368e+00, max vLW: 4.2865e+00
# Iter  6000, Total: 2.3259e-07
# PDE: 2.3259e-07
# For uPDE, min uLW: 1.0465e+00, max uLW: 2.6735e+00
# For vPDE, min vLW: 1.0368e+00, max vLW: 4.3175e+00
# Iter  7000, Total: 1.5281e-07
# PDE: 1.5281e-07
# For uPDE, min uLW: 1.0466e+00, max uLW: 2.6806e+00
# For vPDE, min vLW: 1.0370e+00, max vLW: 4.3247e+00
# Iter  8000, Total: 6.3290e-06
# PDE: 6.3290e-06
# For uPDE, min uLW: 1.0506e+00, max uLW: 2.7028e+00
# For vPDE, min vLW: 1.0404e+00, max vLW: 4.3841e+00
# Iter  9000, Total: 9.0120e-06
# PDE: 9.0120e-06
# For uPDE, min uLW: 1.0617e+00, max uLW: 2.7516e+00
# For vPDE, min vLW: 1.0418e+00, max vLW: 4.4821e+00
# Iter 10000, Total: 1.5002e-05
# PDE: 1.5002e-05
# For uPDE, min uLW: 1.0724e+00, max uLW: 2.7865e+00
# For vPDE, min vLW: 1.0424e+00, max vLW: 4.5951e+00
# Iter 11000, Total: 1.6516e-05
# PDE: 1.6516e-05
# For uPDE, min uLW: 1.0838e+00, max uLW: 3.6212e+00
# For vPDE, min vLW: 1.0430e+00, max vLW: 4.7011e+00
# Iter 12000, Total: 1.3627e-05
# PDE: 1.3627e-05
# For uPDE, min uLW: 1.0978e+00, max uLW: 4.7724e+00
# For vPDE, min vLW: 1.0436e+00, max vLW: 4.7986e+00
# Iter 13000, Total: 9.0937e-07
# PDE: 9.0937e-07
# For uPDE, min uLW: 1.1141e+00, max uLW: 6.0126e+00
# For vPDE, min vLW: 1.0444e+00, max vLW: 4.8837e+00
# Iter 14000, Total: 2.1979e-05
# PDE: 2.1979e-05
# For uPDE, min uLW: 1.1307e+00, max uLW: 7.2559e+00
# For vPDE, min vLW: 1.0452e+00, max vLW: 4.9622e+00
# Iter 15000, Total: 1.6938e-05
# PDE: 1.6938e-05
# For uPDE, min uLW: 1.2470e+00, max uLW: 8.4755e+00
# For vPDE, min vLW: 1.0625e+00, max vLW: 5.2890e+00
# Iter 16000, Total: 1.1661e-06
# PDE: 1.1661e-06
# For uPDE, min uLW: 1.2617e+00, max uLW: 9.5706e+00
# For vPDE, min vLW: 1.0636e+00, max vLW: 5.3194e+00
# Iter 17000, Total: 1.5424e-06
# PDE: 1.5424e-06
# For uPDE, min uLW: 1.2752e+00, max uLW: 1.0735e+01
# For vPDE, min vLW: 1.0642e+00, max vLW: 5.3552e+00
# Iter 18000, Total: 2.1242e-05
# PDE: 2.1242e-05
# For uPDE, min uLW: 1.2888e+00, max uLW: 1.1926e+01
# For vPDE, min vLW: 1.0650e+00, max vLW: 5.3952e+00
# Iter 19000, Total: 2.5500e-05
# PDE: 2.5500e-05
# For uPDE, min uLW: 1.3028e+00, max uLW: 1.3123e+01
# For vPDE, min vLW: 1.0660e+00, max vLW: 5.5005e+00
# Iter 20000, Total: 1.9358e-06
# PDE: 1.9358e-06
# For uPDE, min uLW: 1.3179e+00, max uLW: 1.4324e+01
# For vPDE, min vLW: 1.0674e+00, max vLW: 5.7720e+00
# Iter 21000, Total: 3.8553e-05
# PDE: 3.8553e-05
# For uPDE, min uLW: 1.3303e+00, max uLW: 1.5458e+01
# For vPDE, min vLW: 1.0681e+00, max vLW: 5.9906e+00
# Iter 22000, Total: 2.5574e-05
# PDE: 2.5574e-05
# For uPDE, min uLW: 1.3413e+00, max uLW: 1.6637e+01
# For vPDE, min vLW: 1.0696e+00, max vLW: 6.2613e+00
# Iter 23000, Total: 1.9126e-05
# PDE: 1.9126e-05
# For uPDE, min uLW: 1.3526e+00, max uLW: 1.7777e+01
# For vPDE, min vLW: 1.0716e+00, max vLW: 6.5352e+00
# Iter 24000, Total: 2.7752e-05
# PDE: 2.7752e-05
# For uPDE, min uLW: 1.3658e+00, max uLW: 1.8966e+01
# For vPDE, min vLW: 1.0744e+00, max vLW: 6.8463e+00
# Iter 25000, Total: 4.3602e-06
# PDE: 4.3602e-06
# For uPDE, min uLW: 1.3715e+00, max uLW: 1.9926e+01
# For vPDE, min vLW: 1.0761e+00, max vLW: 7.0290e+00
# Iter 26000, Total: 2.8314e-05
# PDE: 2.8314e-05
# For uPDE, min uLW: 1.3796e+00, max uLW: 2.0991e+01
# For vPDE, min vLW: 1.0778e+00, max vLW: 7.2330e+00
# Iter 27000, Total: 1.3024e-05
# PDE: 1.3024e-05
# For uPDE, min uLW: 1.7348e+00, max uLW: 2.2644e+01
# For vPDE, min vLW: 1.2425e+00, max vLW: 8.4975e+00
# Iter 28000, Total: 1.7189e-06
# PDE: 1.7189e-06
# For uPDE, min uLW: 1.7378e+00, max uLW: 2.2750e+01
# For vPDE, min vLW: 1.2546e+00, max vLW: 8.5778e+00
# Iter 29000, Total: 2.8796e-06
# PDE: 2.8796e-06
# For uPDE, min uLW: 1.7411e+00, max uLW: 2.3014e+01
# For vPDE, min vLW: 1.2592e+00, max vLW: 8.6283e+00
# Iter 30000, Total: 2.9720e-05
# PDE: 2.9720e-05
# For uPDE, min uLW: 1.7449e+00, max uLW: 2.3414e+01
# For vPDE, min vLW: 1.2608e+00, max vLW: 8.6821e+00
# Iter 31000, Total: 6.5169e-05
# PDE: 6.5169e-05
# For uPDE, min uLW: 1.7498e+00, max uLW: 2.3973e+01
# For vPDE, min vLW: 1.2618e+00, max vLW: 8.7437e+00
# Iter 32000, Total: 3.3142e-05
# PDE: 3.3142e-05
# For uPDE, min uLW: 1.7544e+00, max uLW: 2.4679e+01
# For vPDE, min vLW: 1.2628e+00, max vLW: 8.8057e+00
# Iter 33000, Total: 1.6600e-05
# PDE: 1.6600e-05
# For uPDE, min uLW: 1.7585e+00, max uLW: 2.5493e+01
# For vPDE, min vLW: 1.2643e+00, max vLW: 8.8697e+00
# Iter 34000, Total: 6.0061e-06
# PDE: 6.0061e-06
# For uPDE, min uLW: 1.7626e+00, max uLW: 2.6381e+01
# For vPDE, min vLW: 1.2665e+00, max vLW: 8.9337e+00
# Iter 35000, Total: 1.4255e-05
# PDE: 1.4255e-05
# For uPDE, min uLW: 1.7684e+00, max uLW: 2.7343e+01
# For vPDE, min vLW: 1.2700e+00, max vLW: 9.0024e+00
# Iter 36000, Total: 1.6911e-05
# PDE: 1.6911e-05
# For uPDE, min uLW: 1.7980e+00, max uLW: 2.8467e+01
# For vPDE, min vLW: 1.2795e+00, max vLW: 9.2377e+00
# Iter 37000, Total: 3.8317e-05
# PDE: 3.8317e-05
# For uPDE, min uLW: 1.8029e+00, max uLW: 2.9105e+01
# For vPDE, min vLW: 1.2878e+00, max vLW: 9.3773e+00
# Iter 38000, Total: 4.3347e-05
# PDE: 4.3347e-05
# For uPDE, min uLW: 1.8067e+00, max uLW: 2.9922e+01
# For vPDE, min vLW: 1.2931e+00, max vLW: 9.5364e+00
# Iter 39000, Total: 5.0834e-06
# PDE: 5.0834e-06
# For uPDE, min uLW: 1.8117e+00, max uLW: 3.0808e+01
# For vPDE, min vLW: 1.2989e+00, max vLW: 9.6871e+00
# Iter 40000, Total: 2.5379e-05
# PDE: 2.5379e-05
# For uPDE, min uLW: 1.8161e+00, max uLW: 3.1614e+01
# For vPDE, min vLW: 1.3043e+00, max vLW: 9.8131e+00
# Iter 41000, Total: 9.5150e-05
# PDE: 9.5150e-05
# For uPDE, min uLW: 2.0960e+00, max uLW: 3.2408e+01
# For vPDE, min vLW: 1.8378e+00, max vLW: 1.0722e+01
# Iter 42000, Total: 8.1855e-05
# PDE: 8.1855e-05
# For uPDE, min uLW: 2.0980e+00, max uLW: 3.2424e+01
# For vPDE, min vLW: 1.8657e+00, max vLW: 1.0748e+01
# Iter 43000, Total: 2.1775e-04
# PDE: 2.1775e-04
# For uPDE, min uLW: 2.1009e+00, max uLW: 3.2453e+01
# For vPDE, min vLW: 1.8818e+00, max vLW: 1.0798e+01
# Iter 44000, Total: 8.4893e-05
# PDE: 8.4893e-05
# For uPDE, min uLW: 2.1043e+00, max uLW: 3.2499e+01
# For vPDE, min vLW: 1.8861e+00, max vLW: 1.0864e+01
# Iter 45000, Total: 2.7503e-05
# PDE: 2.7503e-05
# For uPDE, min uLW: 2.1090e+00, max uLW: 3.2577e+01
# For vPDE, min vLW: 1.8876e+00, max vLW: 1.0964e+01
# Iter 46000, Total: 4.3853e-05
# PDE: 4.3853e-05
# For uPDE, min uLW: 2.1149e+00, max uLW: 3.2701e+01
# For vPDE, min vLW: 1.8907e+00, max vLW: 1.1097e+01
# Iter 47000, Total: 1.3391e-04
# PDE: 1.3391e-04
# For uPDE, min uLW: 2.1218e+00, max uLW: 3.2894e+01
# For vPDE, min vLW: 1.8975e+00, max vLW: 1.1252e+01
# Iter 48000, Total: 4.1587e-05
# PDE: 4.1587e-05
# For uPDE, min uLW: 2.1295e+00, max uLW: 3.3179e+01
# For vPDE, min vLW: 1.9099e+00, max vLW: 1.1409e+01
# Iter 49000, Total: 2.2804e-04
# PDE: 2.2804e-04
# For uPDE, min uLW: 2.1396e+00, max uLW: 3.3593e+01
# For vPDE, min vLW: 1.9236e+00, max vLW: 1.1585e+01
# Iter 50000, Total: 7.8590e-05
# PDE: 7.8590e-05
# For uPDE, min uLW: 2.1509e+00, max uLW: 3.4181e+01
# For vPDE, min vLW: 1.9318e+00, max vLW: 1.1991e+01
# Starting with L-BFGS

# %%
# apply PINN to the same grid as the quadrature solution for comparison
t = np.linspace(tlo, thi, 201)
x = np.linspace(xlo, xhi, 1001)
T, X = np.meshgrid(t, x)
pts_flat = np.hstack((T.flatten()[:, None], X.flatten()[:, None]))
u_pred, v_pred = model.predict(pts_flat)           
u_pred = griddata(pts_flat, u_pred.flatten(), (T, X), method='cubic')
v_pred = griddata(pts_flat, v_pred.flatten(), (T, X), method='cubic')

# %% [markdown]
# ## Visualizations

# %%
data = scipy.io.loadmat('/Users/abraham/Desktop/PINN/New_Data/GS_1D_t20.mat')
t = data['t'].flatten()[:,None]
x2 = data['x'].flatten()[:,None]
u_sol = np.real(data['u_sol']).T
v_sol = np.real(data['v_sol']).T

# %%
####### Row 1: u(t,x) slices ################## 

""" The aesthetic setting has changed. """

fig = plt.figure(figsize=(18, 6))
#
ax = plt.subplot(1, 3, 1)
ax.plot(x2, u_sol[0,:], 'bo-', linewidth = 2, label = 'Exact')       
ax.plot(x, u_pred[:, 0], 'rx--', linewidth = 2, label = 'u')
ax.set_xlabel('$x$')
ax.set_ylabel('$u(t,x)$')    
ax.set_title('$t = %.1f$' %(t[0]), fontsize = 24)



plt.locator_params(axis = 'y', nbins = 5)
plt.locator_params(axis = 'x', nbins = 5)
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(24)

ax = plt.subplot(1, 3, 2)
ax.plot(x2,u_sol[100,:], 'b-', linewidth = 2, label = 'Exact')       
ax.plot(x, u_pred[:, 100], 'rx--', linewidth = 2, label = 'u')
ax.set_xlabel('$x$')




ax.set_title('$t = %.1f$' %(t[100]), fontsize = 24)
ax.legend(
    loc='upper center', 
    bbox_to_anchor=(0.5, -0.15), 
    ncol=5, 
    frameon=False, 
    prop={'size': 24}
)
plt.locator_params(axis = 'y', nbins = 5)
plt.locator_params(axis = 'x', nbins = 5)
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(24)

ax = plt.subplot(1, 3, 3)
ax.plot(x2,u_sol[200,:], 'b-', linewidth = 2, label = 'Exact')       
ax.plot(x, u_pred[:, 200], 'rx--', linewidth = 2, label = 'u')
ax.set_xlabel('$x$')



ax.set_title('$t = %.1f$' %(t[200]), fontsize = 24)
plt.locator_params(axis = 'y', nbins = 5)
plt.locator_params(axis = 'x', nbins = 5)
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(24)

plt.show()
fig.savefig('GSu_1D_BL+PBC+IC2+SA.png',format='png')

# %%
fig = plt.figure(figsize=(18, 6))
#
ax = plt.subplot(1, 3, 1)
ax.plot(x2, v_sol[0,:], 'bo-', linewidth = 2, label = 'Exact')       
ax.plot(x, v_pred[:, 0], 'rx--', linewidth = 2, label = 'u')
ax.set_xlabel('$x$')
ax.set_ylabel('$u(t,x)$')    
ax.set_title('$t = %.1f$' %(t[0]), fontsize = 24)



plt.locator_params(axis = 'y', nbins = 5)
plt.locator_params(axis = 'x', nbins = 5)
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(24)

ax = plt.subplot(1, 3, 2)
ax.plot(x2,v_sol[100,:], 'b-', linewidth = 2, label = 'Exact')       
ax.plot(x, v_pred[:, 100], 'rx--', linewidth = 2, label = 'u')
ax.set_xlabel('$x$')




ax.set_title('$t = %.1f$' %(t[100]), fontsize = 24)
ax.legend(
    loc='upper center', 
    bbox_to_anchor=(0.5, -0.15), 
    ncol=5, 
    frameon=False, 
    prop={'size': 24}
)
plt.locator_params(axis = 'y', nbins = 5)
plt.locator_params(axis = 'x', nbins = 5)
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(24)

ax = plt.subplot(1, 3, 3)
ax.plot(x2,v_sol[200,:], 'b-', linewidth = 2, label = 'Exact')       
ax.plot(x, v_pred[:, 200], 'rx--', linewidth = 2, label = 'u')
ax.set_xlabel('$x$')



ax.set_title('$t = %.1f$' %(t[200]), fontsize = 24)
plt.locator_params(axis = 'y', nbins = 5)
plt.locator_params(axis = 'x', nbins = 5)
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(24)

plt.show()
fig.savefig('GSv_1D_BL+PBC+IC2+SA.png',format='png')

# %%
def relative_error_l2(pred,exact):
    error_l2 = np.sqrt(np.sum(np.power(pred - exact,2)))
    relative = error_l2/np.sqrt(np.sum(np.power(exact,2)))
    return relative
def relative_error_l1(pred,exact):
    error_l1 = np.sum(np.abs(pred-exact))
    relative = error_l1/np.sum(np.abs(exact))
    return relative
def relative_error_linf(pred,exact):
    error_linf = np.max(np.abs(pred-exact))
    relative = error_linf/np.max(np.abs(exact))
    return relative

# %%
print(f'l2: {relative_error_l2(u_pred.T,u_sol)}')
print(f'l1: {relative_error_l1(u_pred.T,u_sol)}')
print(f'linf: {relative_error_linf(u_pred.T,u_sol)}')
# Out:
# l2: 0.007590834161209268
# l1: 0.003981887959896671
# linf: 0.03952108849394431

# %%
print(f'l2: {relative_error_l2(v_pred.T,v_sol)}')
print(f'l1: {relative_error_l1(v_pred.T,v_sol)}')
print(f'linf: {relative_error_linf(v_pred.T,v_sol)}')
# Out:
# l2: 0.04758076946679128
# l1: 0.03334386777903289
# linf: 0.15132855143306842

# %%
fig = plt.figure(figsize=(24, 6))

ax = plt.subplot(1, 3, 1)
h = ax.imshow(u_sol.T, interpolation='nearest', cmap='rainbow', 
              extent=[tlo, thi, x.min(), x.max()], 
              origin='lower', aspect='auto')
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.10)
cbar = fig.colorbar(h, cax=cax)
cbar.ax.tick_params(labelsize=24) 






ax.set_xlabel('$t$', size=24)
ax.set_ylabel('$x$', size=24)

ax.set_title('$GS: u_{exact}(t,x)$', fontsize = 24) # font size doubled
ax.tick_params(labelsize=24)

ax = plt.subplot(1, 3, 2)
h = ax.imshow(u_pred, interpolation='nearest', cmap='rainbow', 
              extent=[tlo, thi, x.min(), x.max()], 
              origin='lower', aspect='auto')
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.10)
cbar = fig.colorbar(h, cax=cax)
cbar.ax.tick_params(labelsize=24) 




ax.set_xlabel('$t$', size=24)


ax.set_title('$GS: u_{pred}(t,x)$', fontsize = 24) # font size doubled
ax.tick_params(labelsize=24)

ax = plt.subplot(1, 3, 3)
h = ax.imshow(np.abs(u_pred-u_sol.T), interpolation='nearest', cmap='rainbow', 
              extent=[tlo, thi, x.min(), x.max()], 
              origin='lower', aspect='auto')
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.10)
cbar = fig.colorbar(h, cax=cax)
cbar.ax.tick_params(labelsize=24) 




ax.set_xlabel('$t$', size=24)


ax.set_title('$GS(Error): u(t,x)$', fontsize = 24) # font size doubled
ax.tick_params(labelsize=24)


plt.show()
fig.savefig('GS3u_1D_BL+PBC+IC2+SA.png',format='png')

# %%
fig = plt.figure(figsize=(24, 6))

ax = plt.subplot(1, 3, 1)
h = ax.imshow(v_sol.T, interpolation='nearest', cmap='rainbow', 
              extent=[tlo, thi, x.min(), x.max()], 
              origin='lower', aspect='auto')
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.10)
cbar = fig.colorbar(h, cax=cax)
cbar.ax.tick_params(labelsize=24) 






ax.set_xlabel('$t$', size=24)
ax.set_ylabel('$x$', size=24)

ax.set_title('$GS: v_{exact}(t,x)$', fontsize = 24) # font size doubled
ax.tick_params(labelsize=24)

ax = plt.subplot(1, 3, 2)
h = ax.imshow(v_pred, interpolation='nearest', cmap='rainbow', 
              extent=[tlo, thi, x.min(), x.max()], 
              origin='lower', aspect='auto')
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.10)
cbar = fig.colorbar(h, cax=cax)
cbar.ax.tick_params(labelsize=24) 





ax.set_xlabel('$t$', size=24)


ax.set_title('$GS: v_{pred}(t,x)$', fontsize = 24) # font size doubled
ax.tick_params(labelsize=24)

ax = plt.subplot(1, 3, 3)
h = ax.imshow(np.abs(v_pred-v_sol.T), interpolation='nearest', cmap='rainbow', 
              extent=[tlo, thi, x.min(), x.max()], 
              origin='lower', aspect='auto')
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.10)
cbar = fig.colorbar(h, cax=cax)
cbar.ax.tick_params(labelsize=24) 




ax.set_xlabel('$t$', size=24)


ax.set_title('$GS(Error): v(t,x)$', fontsize = 24) # font size doubled
ax.tick_params(labelsize=24)


plt.show()
fig.savefig('GS3v_1D_BL+PBC+IC2+SA.png',format='png')
