# %% [markdown]
# # PINN Solution of the Gray Scott PDEs
#
# This PyTorch code demonstrates the application of physically-informed neural networks (PINN) in the solution of a well-known Gray Scott PDEs with periodic boundary condition
# \begin{aligned}
#   &u_t = \epsilon_1\Delta u + b(1 - u) - uv^2, \quad (t, x) \in [0, T]\times[-L, L]\\
#   &v_t = \epsilon_2\Delta v -dv + uv^2, \\
#   &u(0, x) = u_0(x), \quad v(0, x) = v_0(x), \quad \forall x \in [-L, L] \\
#   &u(t, -L) = u(t, L), \quad v(t, -L) = v(t, L), \quad \forall t \in [0, T]
# \end{aligned}
# where $\epsilon_1, \epsilon_2, b, d > 0$ are some parameters, and $[x_{\min}, x_{\max}]$ covers one full period.
#
# See [this link](https://www.chebfun.org/examples/pde/GrayScott.html) for a description

# %% [markdown]
# ## Libraries and Dependencies

# %%
import torch
import torch.optim
import torch.optim.lr_scheduler as lr_scheduler
from itertools import chain
from collections import OrderedDict
from pyDOE import lhs
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import scipy.io
from scipy.interpolate import griddata
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.gridspec as gridspec
import time
# set the random seed
np.random.seed(1234)

# %%
if torch.backends.mps.is_available():
    device = torch.device('mps')
elif torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
#
print(f"Working on {device}")
# Out:
# Working on mps

# %%
epsilon1 = 1
epsilon2 = 1e-2
b = 2e-2
d = 8.62e-2
L = 50.0
xlo = -L
xhi = L
period = xhi - xlo
tlo = 0.0
thi = 20.0
pi_ten = torch.tensor(np.pi).float().to(device)
L_ten = torch.tensor(L).float().to(device)
u0 = lambda x: 1.0 - 0.5 * np.power(np.sin(np.pi * (x - L)/(2.0 * L)), 4.0)
u0_ten = lambda x: 1.0 - 0.5 * torch.pow(torch.sin(pi_ten * (x - L_ten)/(2.0 * L_ten)), 4.0)
v0 = lambda x: 0.25 * np.power(np.sin(np.pi * (x - L)/(2.0 * L)), 4.0)
v0_ten = lambda x: 0.25 * torch.pow(torch.sin(pi_ten * (x - L_ten)/(2.0 * L_ten)), 4.0)

# %% [markdown]
# ## Physics-informed Neural Networks

# %%
# the deep neural network
class DNN(torch.nn.Module):
    def __init__(self, layers):
        super(DNN, self).__init__()
        # parameters
        self.depth = len(layers) - 1
        # set up layer order dict
        self.activation = torch.nn.Tanh
        layer_list = list()
        for i in range(self.depth - 1): 
            layer_list.append(
                ('layer_%d' % i, torch.nn.Linear(layers[i], layers[i+1]))
            )
            layer_list.append(('activation_%d' % i, self.activation()))
            
        layer_list.append(
            ('layer_%d' % (self.depth - 1), torch.nn.Linear(layers[-2], layers[-1]))
        )
        layerDict = OrderedDict(layer_list)
        # deploy layers
        self.layers = torch.nn.Sequential(layerDict)
        self.layers[0].weight = torch.load('initial_weight.pt')
    def forward(self, x):
        out = self.layers(x)
        return out

# %%
class PhysicsInformedNN():
    def __init__(self, period, epsilon1,epsilon2, X_IC, u_IC, v_IC, X_BC, u_BC, v_BC, X_PDE, layers, b, d):
        # IC data point
        self.t_IC = torch.tensor(X_IC[:, 0:1]).float().to(device)
        self.x_IC = torch.tensor(X_IC[:, 1:2]).float().to(device)
        self.u_IC = torch.tensor(u_IC).float().to(device)
        self.v_IC = torch.tensor(v_IC).float().to(device) 
        N_IC = X_IC.shape[0]
        self.LW_uIC = torch.nn.ParameterList([torch.nn.Parameter(torch.ones(N_IC, 1).float(), requires_grad=True).to(device)])
        self.LW_vIC = torch.nn.ParameterList([torch.nn.Parameter(torch.ones(N_IC, 1).float(), requires_grad=True).to(device)])
        # BC data point
        self.t_BC = torch.tensor(X_BC[:, 0:1]).float().to(device)
        self.x_BC = torch.tensor(X_BC[:, 1:2]).float().to(device)
        self.u_BC = torch.tensor(u_BC).float().to(device)
        self.v_BC = torch.tensor(v_BC).float().to(device) 
        self.period = torch.tensor(period).float().to(device)
        N_BC = X_BC.shape[0]
        self.LW_uBC = torch.nn.ParameterList([torch.nn.Parameter(torch.ones(N_BC, 1).float(), requires_grad=True).to(device)])        
        self.LW_vBC = torch.nn.ParameterList([torch.nn.Parameter(torch.ones(N_BC, 1).float(), requires_grad=True).to(device)])        
        # PDE data, gradients will be computed on these points so requires_grad = True
        self.t_PDE = torch.tensor(X_PDE[:, 0:1], requires_grad=True).float().to(device)
        self.x_PDE = torch.tensor(X_PDE[:, 1:2], requires_grad=True).float().to(device)
       
        N_PDE = X_PDE.shape[0]
        self.LW_uPDE = torch.nn.ParameterList([torch.nn.Parameter(torch.ones(N_PDE, 1).float(), requires_grad=True).to(device)])
        self.LW_vPDE = torch.nn.ParameterList([torch.nn.Parameter(torch.ones(N_PDE, 1).float(), requires_grad=True).to(device)])

        # equation related parameters
        self.epsilon1 = torch.tensor(epsilon1).float().to(device)
        self.epsilon2 = torch.tensor(epsilon2).float().to(device)
        self.b = b
        self.d = d
        # layers to build Neural Net
        self.layers = layers
        # deep neural networks
        self.dnn = DNN(layers).to(device)    
        # prepare the optimizer
        self.optimizer_Adam = torch.optim.Adam(self.dnn.parameters(), lr = 1e-3)
        self.optimizer_LW_uIC = torch.optim.Adam(self.LW_uIC.parameters(), lr = 5e-3)
        self.optimizer_LW_uBC = torch.optim.Adam(self.LW_uBC.parameters(), lr = 5e-3)
        self.optimizer_LW_uPDE = torch.optim.Adam(self.LW_uPDE.parameters(), lr = 5e-3)
        self.optimizer_LW_vIC = torch.optim.Adam(self.LW_vIC.parameters(), lr = 5e-3)
        self.optimizer_LW_vBC = torch.optim.Adam(self.LW_vBC.parameters(), lr = 5e-3)
        self.optimizer_LW_vPDE = torch.optim.Adam(self.LW_vPDE.parameters(), lr = 5e-3)
        # add a learning rate scheduler
        
        self.optimizer_LBFGS = torch.optim.LBFGS(
            self.dnn.parameters(), 
            lr=1.0, 
            max_iter=50000, 
            max_eval=50000, 
            history_size=50,
            tolerance_grad=1e-8, 
            tolerance_change=1.0 * np.finfo(float).eps,
            line_search_fn="strong_wolfe"       # can be "strong_wolfe"
        )        
        
        self.iter = 0
    # evaluater neural network, no transformation
    def NN_eval(self, t, x):  
        NN = self.dnn(torch.cat([t, x], dim = 1)) 
        u = NN[:, 0][:, None]
        v = NN[:, 1][:, None]
        return u,v
    # compute the PDE
    def pde_eval(self, t, x):
        """ The pytorch autograd version of calculating residual """
        u, v = self.NN_eval(t, x)
        # compute the derivatives for u
        u_t  = torch.autograd.grad(u,   t, grad_outputs = torch.ones_like(u), retain_graph = True, create_graph=True)[0]
        u_x  = torch.autograd.grad(u,   x, grad_outputs = torch.ones_like(u), retain_graph = True, create_graph=True)[0]
        u_xx = torch.autograd.grad(u_x, x, grad_outputs = torch.ones_like(u), retain_graph = True, create_graph=True)[0]
        v_t = torch.autograd.grad(v, t, grad_outputs = torch.ones_like(v), retain_graph = True, create_graph=True)[0]
        v_x = torch.autograd.grad(v, x, grad_outputs = torch.ones_like(v), retain_graph = True, create_graph=True)[0]
        v_xx = torch.autograd.grad(v_x, x, grad_outputs = torch.ones_like(v), retain_graph = True, create_graph=True)[0]
        Eq1 = u_t - self.epsilon1 * u_xx - self.b * (1.0 - u) + u * torch.pow(v, 2.0)
        Eq2 = v_t - self.epsilon2 * v_xx + self.d * v - u * torch.pow(v, 2.0)
        return Eq1, Eq2
    # compute the total loss for the second-order optimizer
    def loss_func(self):
        # reset the gradient
        self.optimizer_LBFGS.zero_grad()
        # compute IC loss
        uIC_pred, vIC_pred = self.NN_eval(self.t_IC, self.x_IC)
    
        loss_IC = torch.mean((self.LW_uIC[0] *(self.u_IC - uIC_pred))**2.0) + torch.mean((self.LW_vIC[0] *(self.v_IC - vIC_pred))**2.0)
        # compute PBC loss
        uBC_pred_left, vBC_pred_left = self.NN_eval(self.t_BC, self.x_BC)
        uBC_pred_right, vBC_pred_right = self.NN_eval(self.t_BC, self.x_BC+self.period)
        loss_BC = torch.mean((self.LW_uBC[0]*(uBC_pred_left - uBC_pred_right))**2.0) + torch.mean((self.LW_vBC[0]*(vBC_pred_left - vBC_pred_right))**2.0)
        
        
        pde1_pred, pde2_pred = self.pde_eval(self.t_PDE, self.x_PDE)
        loss_PDE = torch.mean((self.LW_uPDE[0]*pde1_pred )** 2) + torch.mean((self.LW_vPDE[0]*pde2_pred )** 2)   
        
       
        # compute the total loss, it can be weighted
        loss = loss_IC + loss_BC + loss_PDE
        # backward propagation
        loss.backward()
        # increase the iteration counter
        self.iter += 1
        # output
        # output the progress
        if self.iter % 1000 == 0:
            end_time = time.time()
            print('Iter %5d, Total: %10.4e' % (self.iter, loss.item()))
            print('IC: %10.4e, PBC: %10.4e, PDE: %10.4e' % (loss_IC.item(), loss_BC.item(), loss_PDE.item()))
            self.start_time = end_time
        return loss
    #
    def train(self, nIter):
        # start the timer
        start_time = time.time()        
        # start the training with Adam first
        self.dnn.train()
        print('Starting with Adam')
        for epoch in range(nIter):
            # compute IC loss
            uIC_pred, vIC_pred = self.NN_eval(self.t_IC, self.x_IC)
    
            loss_IC = torch.mean((self.LW_uIC[0] *(self.u_IC - uIC_pred))**2.0) + torch.mean((self.LW_vIC[0] *(self.v_IC - vIC_pred))**2.0)
        # compute PBC loss
            uBC_pred_left, vBC_pred_left = self.NN_eval(self.t_BC, self.x_BC)
            uBC_pred_right, vBC_pred_right = self.NN_eval(self.t_BC, self.x_BC+self.period)
            loss_BC = torch.mean((self.LW_uBC[0]*(uBC_pred_left - uBC_pred_right))**2.0) + torch.mean((self.LW_vBC[0]*(vBC_pred_left - vBC_pred_right))**2.0)
        
        
            pde1_pred, pde2_pred = self.pde_eval(self.t_PDE, self.x_PDE)
            loss_PDE = torch.mean((self.LW_uPDE[0]*pde1_pred )** 2) + torch.mean((self.LW_vPDE[0]*pde2_pred )** 2)   
        
       
        # compute the total loss, it can be weighted
            loss = loss_IC + loss_BC + loss_PDE
            # Backward and optimize
            self.optimizer_Adam.zero_grad()
            self.optimizer_LW_uIC.zero_grad()
            self.optimizer_LW_uBC.zero_grad()
            self.optimizer_LW_uPDE.zero_grad()
            self.optimizer_LW_vIC.zero_grad()
            self.optimizer_LW_vBC.zero_grad()
            self.optimizer_LW_vPDE.zero_grad()
            loss.backward()
            self.optimizer_Adam.step() 
            self.LW_uIC[0].grad.data = -self.LW_uIC[0].grad.data
            self.LW_uBC[0].grad.data = -self.LW_uBC[0].grad.data
            self.LW_uPDE[0].grad.data = -self.LW_uPDE[0].grad.data
            self.LW_vIC[0].grad.data = -self.LW_vIC[0].grad.data
            self.LW_vBC[0].grad.data = -self.LW_vBC[0].grad.data
            self.LW_vPDE[0].grad.data = -self.LW_vPDE[0].grad.data
            self.optimizer_LW_uIC.step()
            self.optimizer_LW_uBC.step()
            self.optimizer_LW_uPDE.step()
            self.optimizer_LW_vIC.step()
            self.optimizer_LW_vBC.step()
            self.optimizer_LW_vPDE.step()
            # output the progress
            if (epoch + 1) % 1000 == 0:
                end_time = time.time()
                print('Iter %5d, Total: %10.4e' % (epoch + 1, loss.item()))
                print('IC: %10.4e, PBC: %10.4e, PDE: %10.4e' % (loss_IC.item(), loss_BC.item(), loss_PDE.item()))
                print('For uIC,  min uLW: %10.4e, max uLW: %10.4e' %(torch.min(self.LW_uIC[0]).item(), torch.max(self.LW_uIC[0]).item()))
                print('For uBC,  min uLW: %10.4e, max uLW: %10.4e' %(torch.min(self.LW_uBC[0]).item(), torch.max(self.LW_uBC[0]).item()))
                print('For uPDE, min uLW: %10.4e, max uLW: %10.4e' %(torch.min(self.LW_uPDE[0]).item(), torch.max(self.LW_uPDE[0]).item()))
                print('For vIC,  min vLW: %10.4e, max vLW: %10.4e' %(torch.min(self.LW_vIC[0]).item(), torch.max(self.LW_vIC[0]).item()))
                print('For vBC,  min vLW: %10.4e, max vLW: %10.4e' %(torch.min(self.LW_vBC[0]).item(), torch.max(self.LW_vBC[0]).item()))
                print('For vPDE, min vLW: %10.4e, max vLW: %10.4e' %(torch.min(self.LW_vPDE[0]).item(), torch.max(self.LW_vPDE[0]).item()))
                
                start_time = end_time
                # change the learning rate
                
        # Using the second-order L-BFGS optimizer
        print('Starting with L-BFGS')
        
        self.optimizer_LBFGS.step(self.loss_func)                
    #        
    def predict(self, X):
        t = torch.tensor(X[:, 0:1], requires_grad=True).float().to(device)
        x = torch.tensor(X[:, 1:2], requires_grad=True).float().to(device)
        self.dnn.eval()
        u, v = self.NN_eval(t, x)
        u = u.detach().cpu().numpy()
        v = v.detach().cpu().numpy()
        return u,v


## Configurations

# %% [markdown]
# ## Training

# %%
layers = [2, 32, 32, 32, 32, 32, 32, 32, 2]
N_IC = 128
ptsIC=np.load('ptsIC.npy')
ptsBC=np.load('ptsBC.npy')
ptsPDE=np.load('random_data.npy')
uBC = np.load('uBC.npy')
vBC = np.load('vBC.npy')
x_IC = np.expand_dims(np.linspace(xlo, xhi, N_IC), axis = 1)
uIC = u0(x_IC)
vIC = v0(x_IC)
model = PhysicsInformedNN(period, epsilon1, epsilon2, ptsIC, uIC, vIC, ptsBC, uBC, vBC, ptsPDE, layers, b, d)
model.train(50000)
# Out:
# Starting with Adam
# Iter  1000, Total: 1.5214e-03
# IC: 8.6590e-04, PBC: 1.3940e-05, PDE: 6.4154e-04
# For uIC,  min uLW: 1.1060e+00, max uLW: 1.1384e+00
# For uBC,  min uLW: 1.0813e+00, max uLW: 1.2956e+00
# For uPDE, min uLW: 1.0789e+00, max uLW: 3.3053e+00
# For vIC,  min vLW: 1.0789e+00, max vLW: 1.3714e+00
# For vBC,  min vLW: 1.1353e+00, max vLW: 1.2632e+00
# For vPDE, min vLW: 1.0520e+00, max vLW: 1.2560e+00
# Iter  2000, Total: 9.1332e-04
# IC: 3.2855e-04, PBC: 9.8009e-06, PDE: 5.7497e-04
# For uIC,  min uLW: 1.1060e+00, max uLW: 1.1387e+00
# For uBC,  min uLW: 1.0815e+00, max uLW: 1.2961e+00
# For uPDE, min uLW: 1.0792e+00, max uLW: 3.4570e+00
# For vIC,  min vLW: 1.0789e+00, max vLW: 1.3734e+00
# For vBC,  min vLW: 1.1355e+00, max vLW: 1.2681e+00
# For vPDE, min vLW: 1.0520e+00, max vLW: 1.2806e+00
# Iter  3000, Total: 7.7093e-04
# IC: 2.2243e-04, PBC: 8.7577e-06, PDE: 5.3974e-04
# For uIC,  min uLW: 1.1060e+00, max uLW: 1.1388e+00
# For uBC,  min uLW: 1.0818e+00, max uLW: 1.2961e+00
# For uPDE, min uLW: 1.0792e+00, max uLW: 3.5110e+00
# For vIC,  min vLW: 1.0789e+00, max vLW: 1.3740e+00
# For vBC,  min vLW: 1.1355e+00, max vLW: 1.2720e+00
# For vPDE, min vLW: 1.0521e+00, max vLW: 1.2963e+00
# Iter  4000, Total: 6.9722e-04
# IC: 1.8474e-04, PBC: 8.4422e-06, PDE: 5.0403e-04
# For uIC,  min uLW: 1.1060e+00, max uLW: 1.1389e+00
# For uBC,  min uLW: 1.0827e+00, max uLW: 1.2961e+00
# For uPDE, min uLW: 1.0792e+00, max uLW: 3.5332e+00
# For vIC,  min vLW: 1.0790e+00, max vLW: 1.3743e+00
# For vBC,  min vLW: 1.1355e+00, max vLW: 1.2765e+00
# For vPDE, min vLW: 1.0521e+00, max vLW: 1.3078e+00
# Iter  5000, Total: 6.2236e-04
# IC: 1.5990e-04, PBC: 7.7451e-06, PDE: 4.5471e-04
# For uIC,  min uLW: 1.1060e+00, max uLW: 1.1389e+00
# For uBC,  min uLW: 1.0842e+00, max uLW: 1.2962e+00
# For uPDE, min uLW: 1.0793e+00, max uLW: 3.5421e+00
# For vIC,  min vLW: 1.0792e+00, max vLW: 1.3745e+00
# For vBC,  min vLW: 1.1356e+00, max vLW: 1.2804e+00
# For vPDE, min vLW: 1.0521e+00, max vLW: 1.3167e+00
# Iter  6000, Total: 5.3867e-04
# IC: 1.3785e-04, PBC: 6.7265e-06, PDE: 3.9409e-04
# For uIC,  min uLW: 1.1060e+00, max uLW: 1.1389e+00
# For uBC,  min uLW: 1.0870e+00, max uLW: 1.2966e+00
# For uPDE, min uLW: 1.0794e+00, max uLW: 3.5454e+00
# For vIC,  min vLW: 1.0793e+00, max vLW: 1.3746e+00
# For vBC,  min vLW: 1.1361e+00, max vLW: 1.2823e+00
# For vPDE, min vLW: 1.0521e+00, max vLW: 1.3233e+00
# Iter  7000, Total: 4.3885e-04
# IC: 1.1715e-04, PBC: 4.5734e-06, PDE: 3.1712e-04
# For uIC,  min uLW: 1.1060e+00, max uLW: 1.1389e+00
# For uBC,  min uLW: 1.0901e+00, max uLW: 1.2970e+00
# For uPDE, min uLW: 1.0797e+00, max uLW: 3.5462e+00
# For vIC,  min vLW: 1.0796e+00, max vLW: 1.3747e+00
# For vBC,  min vLW: 1.1368e+00, max vLW: 1.2826e+00
# For vPDE, min vLW: 1.0521e+00, max vLW: 1.3276e+00
# Iter  8000, Total: 3.4341e-04
# IC: 9.8187e-05, PBC: 1.2899e-06, PDE: 2.4393e-04
# For uIC,  min uLW: 1.1060e+00, max uLW: 1.1389e+00
# For uBC,  min uLW: 1.0908e+00, max uLW: 1.2978e+00
# For uPDE, min uLW: 1.0798e+00, max uLW: 3.5462e+00
# For vIC,  min vLW: 1.0797e+00, max vLW: 1.3747e+00
# For vBC,  min vLW: 1.1370e+00, max vLW: 1.2827e+00
# For vPDE, min vLW: 1.0521e+00, max vLW: 1.3300e+00
# Iter  9000, Total: 2.8365e-04
# IC: 8.8635e-05, PBC: 1.3344e-06, PDE: 1.9368e-04
# For uIC,  min uLW: 1.1061e+00, max uLW: 1.1389e+00
# For uBC,  min uLW: 1.0911e+00, max uLW: 1.2987e+00
# For uPDE, min uLW: 1.0798e+00, max uLW: 3.5463e+00
# For vIC,  min vLW: 1.0799e+00, max vLW: 1.3747e+00
# For vBC,  min vLW: 1.1370e+00, max vLW: 1.2827e+00
# For vPDE, min vLW: 1.0521e+00, max vLW: 1.3314e+00
# Iter 10000, Total: 2.3162e-04
# IC: 8.1393e-05, PBC: 1.7034e-06, PDE: 1.4853e-04
# For uIC,  min uLW: 1.1062e+00, max uLW: 1.1389e+00
# For uBC,  min uLW: 1.0917e+00, max uLW: 1.2993e+00
# For uPDE, min uLW: 1.0798e+00, max uLW: 3.5625e+00
# For vIC,  min vLW: 1.0800e+00, max vLW: 1.3747e+00
# For vBC,  min vLW: 1.1371e+00, max vLW: 1.2828e+00
# For vPDE, min vLW: 1.0521e+00, max vLW: 1.3320e+00
# Iter 11000, Total: 1.7965e-04
# IC: 7.2870e-05, PBC: 1.6457e-06, PDE: 1.0514e-04
# For uIC,  min uLW: 1.1063e+00, max uLW: 1.1389e+00
# For uBC,  min uLW: 1.0930e+00, max uLW: 1.2994e+00
# For uPDE, min uLW: 1.0800e+00, max uLW: 3.5707e+00
# For vIC,  min vLW: 1.0801e+00, max vLW: 1.3747e+00
# For vBC,  min vLW: 1.1372e+00, max vLW: 1.2831e+00
# For vPDE, min vLW: 1.0521e+00, max vLW: 1.3324e+00
# Iter 12000, Total: 5.0849e-03
# IC: 4.1151e-03, PBC: 6.2781e-04, PDE: 3.4206e-04
# For uIC,  min uLW: 1.3916e+00, max uLW: 2.4891e+00
# For uBC,  min uLW: 1.3009e+00, max uLW: 1.5248e+00
# For uPDE, min uLW: 1.1212e+00, max uLW: 4.2330e+00
# For vIC,  min vLW: 1.5309e+00, max vLW: 2.6197e+00
# For vBC,  min vLW: 1.4523e+00, max vLW: 1.5930e+00
# For vPDE, min vLW: 1.0639e+00, max vLW: 1.3862e+00
# Iter 13000, Total: 1.2400e-03
# IC: 8.0041e-04, PBC: 1.3801e-04, PDE: 3.0154e-04
# For uIC,  min uLW: 1.3918e+00, max uLW: 2.4924e+00
# For uBC,  min uLW: 1.3012e+00, max uLW: 1.5253e+00
# For uPDE, min uLW: 1.1213e+00, max uLW: 4.2911e+00
# For vIC,  min vLW: 1.5646e+00, max vLW: 2.6314e+00
# For vBC,  min vLW: 1.4534e+00, max vLW: 1.5936e+00
# For vPDE, min vLW: 1.0659e+00, max vLW: 1.4048e+00
# Iter 14000, Total: 8.0576e-04
# IC: 4.7768e-04, PBC: 6.6283e-05, PDE: 2.6179e-04
# For uIC,  min uLW: 1.3923e+00, max uLW: 2.4926e+00
# For uBC,  min uLW: 1.3013e+00, max uLW: 1.5254e+00
# For uPDE, min uLW: 1.1219e+00, max uLW: 4.4081e+00
# For vIC,  min vLW: 1.5684e+00, max vLW: 2.6328e+00
# For vBC,  min vLW: 1.4536e+00, max vLW: 1.5938e+00
# For vPDE, min vLW: 1.0663e+00, max vLW: 1.4085e+00
# Iter 15000, Total: 6.5326e-04
# IC: 3.6488e-04, PBC: 3.8731e-05, PDE: 2.4965e-04
# For uIC,  min uLW: 1.3932e+00, max uLW: 2.4926e+00
# For uBC,  min uLW: 1.3013e+00, max uLW: 1.5254e+00
# For uPDE, min uLW: 1.1220e+00, max uLW: 4.5742e+00
# For vIC,  min vLW: 1.5696e+00, max vLW: 2.6333e+00
# For vBC,  min vLW: 1.4538e+00, max vLW: 1.5940e+00
# For vPDE, min vLW: 1.0664e+00, max vLW: 1.4110e+00
# Iter 16000, Total: 5.6197e-04
# IC: 3.0460e-04, PBC: 2.4937e-05, PDE: 2.3243e-04
# For uIC,  min uLW: 1.3946e+00, max uLW: 2.4926e+00
# For uBC,  min uLW: 1.3013e+00, max uLW: 1.5254e+00
# For uPDE, min uLW: 1.1227e+00, max uLW: 4.7004e+00
# For vIC,  min vLW: 1.5701e+00, max vLW: 2.6334e+00
# For vBC,  min vLW: 1.4539e+00, max vLW: 1.5943e+00
# For vPDE, min vLW: 1.0664e+00, max vLW: 1.4127e+00
# Iter 17000, Total: 4.9335e-04
# IC: 2.6591e-04, PBC: 1.7302e-05, PDE: 2.1014e-04
# For uIC,  min uLW: 1.3968e+00, max uLW: 2.4926e+00
# For uBC,  min uLW: 1.3013e+00, max uLW: 1.5256e+00
# For uPDE, min uLW: 1.1238e+00, max uLW: 4.7926e+00
# For vIC,  min vLW: 1.5705e+00, max vLW: 2.6334e+00
# For vBC,  min vLW: 1.4541e+00, max vLW: 1.5945e+00
# For vPDE, min vLW: 1.0664e+00, max vLW: 1.4138e+00
# Iter 18000, Total: 4.3440e-04
# IC: 2.3961e-04, PBC: 1.2559e-05, PDE: 1.8223e-04
# For uIC,  min uLW: 1.4005e+00, max uLW: 2.4926e+00
# For uBC,  min uLW: 1.3013e+00, max uLW: 1.5260e+00
# For uPDE, min uLW: 1.1241e+00, max uLW: 4.8553e+00
# For vIC,  min vLW: 1.5707e+00, max vLW: 2.6334e+00
# For vBC,  min vLW: 1.4541e+00, max vLW: 1.5947e+00
# For vPDE, min vLW: 1.0664e+00, max vLW: 1.4145e+00
# Iter 19000, Total: 3.7252e-04
# IC: 2.1845e-04, PBC: 9.1229e-06, PDE: 1.4494e-04
# For uIC,  min uLW: 1.4063e+00, max uLW: 2.4926e+00
# For uBC,  min uLW: 1.3013e+00, max uLW: 1.5265e+00
# For uPDE, min uLW: 1.1241e+00, max uLW: 4.8917e+00
# For vIC,  min vLW: 1.5710e+00, max vLW: 2.6336e+00
# For vBC,  min vLW: 1.4541e+00, max vLW: 1.5948e+00
# For vPDE, min vLW: 1.0664e+00, max vLW: 1.4152e+00
# Iter 20000, Total: 3.2325e-04
# IC: 1.9704e-04, PBC: 6.8923e-06, PDE: 1.1932e-04
# For uIC,  min uLW: 1.4149e+00, max uLW: 2.4926e+00
# For uBC,  min uLW: 1.3013e+00, max uLW: 1.5272e+00
# For uPDE, min uLW: 1.1241e+00, max uLW: 4.9155e+00
# For vIC,  min vLW: 1.5714e+00, max vLW: 2.6341e+00
# For vBC,  min vLW: 1.4541e+00, max vLW: 1.5948e+00
# For vPDE, min vLW: 1.0664e+00, max vLW: 1.4159e+00
# Iter 21000, Total: 2.8060e-04
# IC: 1.7350e-04, PBC: 5.7009e-06, PDE: 1.0140e-04
# For uIC,  min uLW: 1.4266e+00, max uLW: 2.4926e+00
# For uBC,  min uLW: 1.3014e+00, max uLW: 1.5280e+00
# For uPDE, min uLW: 1.1244e+00, max uLW: 4.9333e+00
# For vIC,  min vLW: 1.5720e+00, max vLW: 2.6350e+00
# For vBC,  min vLW: 1.4543e+00, max vLW: 1.5948e+00
# For vPDE, min vLW: 1.0664e+00, max vLW: 1.4166e+00
# Iter 22000, Total: 2.3858e-04
# IC: 1.4811e-04, PBC: 3.6675e-06, PDE: 8.6797e-05
# For uIC,  min uLW: 1.4408e+00, max uLW: 2.4926e+00
# For uBC,  min uLW: 1.3016e+00, max uLW: 1.5288e+00
# For uPDE, min uLW: 1.1253e+00, max uLW: 4.9460e+00
# For vIC,  min vLW: 1.5726e+00, max vLW: 2.6362e+00
# For vBC,  min vLW: 1.4544e+00, max vLW: 1.5948e+00
# For vPDE, min vLW: 1.0664e+00, max vLW: 1.4174e+00
# Iter 23000, Total: 1.9920e-04
# IC: 1.2156e-04, PBC: 3.0121e-06, PDE: 7.4622e-05
# For uIC,  min uLW: 1.4562e+00, max uLW: 2.4926e+00
# For uBC,  min uLW: 1.3017e+00, max uLW: 1.5293e+00
# For uPDE, min uLW: 1.1254e+00, max uLW: 4.9540e+00
# For vIC,  min vLW: 1.5734e+00, max vLW: 2.6377e+00
# For vBC,  min vLW: 1.4544e+00, max vLW: 1.5948e+00
# For vPDE, min vLW: 1.0664e+00, max vLW: 1.4181e+00
# Iter 24000, Total: 1.6448e-04
# IC: 9.6503e-05, PBC: 2.4735e-06, PDE: 6.5505e-05
# For uIC,  min uLW: 1.4650e+00, max uLW: 2.4926e+00
# For uBC,  min uLW: 1.3017e+00, max uLW: 1.5297e+00
# For uPDE, min uLW: 1.1258e+00, max uLW: 4.9584e+00
# For vIC,  min vLW: 1.5747e+00, max vLW: 2.6396e+00
# For vBC,  min vLW: 1.4544e+00, max vLW: 1.5950e+00
# For vPDE, min vLW: 1.0664e+00, max vLW: 1.4188e+00
# Iter 25000, Total: 1.3761e-04
# IC: 7.7002e-05, PBC: 2.2743e-06, PDE: 5.8338e-05
# For uIC,  min uLW: 1.4743e+00, max uLW: 2.4926e+00
# For uBC,  min uLW: 1.3017e+00, max uLW: 1.5300e+00
# For uPDE, min uLW: 1.1263e+00, max uLW: 4.9608e+00
# For vIC,  min vLW: 1.5768e+00, max vLW: 2.6415e+00
# For vBC,  min vLW: 1.4544e+00, max vLW: 1.5951e+00
# For vPDE, min vLW: 1.0664e+00, max vLW: 1.4194e+00
# Iter 26000, Total: 1.3085e-03
# IC: 8.9057e-04, PBC: 1.6780e-04, PDE: 2.5013e-04
# For uIC,  min uLW: 1.7578e+00, max uLW: 3.7625e+00
# For uBC,  min uLW: 1.5701e+00, max uLW: 1.7935e+00
# For uPDE, min uLW: 1.1470e+00, max uLW: 5.4702e+00
# For vIC,  min vLW: 1.8491e+00, max vLW: 3.9173e+00
# For vBC,  min vLW: 1.7079e+00, max vLW: 1.8545e+00
# For vPDE, min vLW: 1.0773e+00, max vLW: 1.4831e+00
# Iter 27000, Total: 9.9724e-04
# IC: 6.1948e-04, PBC: 1.4121e-04, PDE: 2.3655e-04
# For uIC,  min uLW: 1.7579e+00, max uLW: 3.7625e+00
# For uBC,  min uLW: 1.5702e+00, max uLW: 1.7936e+00
# For uPDE, min uLW: 1.1472e+00, max uLW: 5.5124e+00
# For vIC,  min vLW: 1.8501e+00, max vLW: 3.9173e+00
# For vBC,  min vLW: 1.7079e+00, max vLW: 1.8550e+00
# For vPDE, min vLW: 1.0773e+00, max vLW: 1.4886e+00
# Iter 28000, Total: 8.2178e-04
# IC: 4.7871e-04, PBC: 1.1289e-04, PDE: 2.3018e-04
# For uIC,  min uLW: 1.7579e+00, max uLW: 3.7625e+00
# For uBC,  min uLW: 1.5703e+00, max uLW: 1.7937e+00
# For uPDE, min uLW: 1.1473e+00, max uLW: 5.5447e+00
# For vIC,  min vLW: 1.8508e+00, max vLW: 3.9173e+00
# For vBC,  min vLW: 1.7079e+00, max vLW: 1.8555e+00
# For vPDE, min vLW: 1.0773e+00, max vLW: 1.4918e+00
# Iter 29000, Total: 7.0264e-04
# IC: 3.8731e-04, PBC: 9.1115e-05, PDE: 2.2421e-04
# For uIC,  min uLW: 1.7580e+00, max uLW: 3.7625e+00
# For uBC,  min uLW: 1.5704e+00, max uLW: 1.7940e+00
# For uPDE, min uLW: 1.1473e+00, max uLW: 5.5682e+00
# For vIC,  min vLW: 1.8516e+00, max vLW: 3.9173e+00
# For vBC,  min vLW: 1.7079e+00, max vLW: 1.8560e+00
# For vPDE, min vLW: 1.0773e+00, max vLW: 1.4938e+00
# Iter 30000, Total: 6.1557e-04
# IC: 3.2498e-04, PBC: 7.5174e-05, PDE: 2.1542e-04
# For uIC,  min uLW: 1.7581e+00, max uLW: 3.7625e+00
# For uBC,  min uLW: 1.5707e+00, max uLW: 1.7942e+00
# For uPDE, min uLW: 1.1473e+00, max uLW: 5.5829e+00
# For vIC,  min vLW: 1.8524e+00, max vLW: 3.9173e+00
# For vBC,  min vLW: 1.7079e+00, max vLW: 1.8564e+00
# For vPDE, min vLW: 1.0773e+00, max vLW: 1.4950e+00
# Iter 31000, Total: 5.4991e-04
# IC: 2.8328e-04, PBC: 6.1816e-05, PDE: 2.0481e-04
# For uIC,  min uLW: 1.7583e+00, max uLW: 3.7625e+00
# For uBC,  min uLW: 1.5709e+00, max uLW: 1.7944e+00
# For uPDE, min uLW: 1.1477e+00, max uLW: 5.5896e+00
# For vIC,  min vLW: 1.8537e+00, max vLW: 3.9173e+00
# For vBC,  min vLW: 1.7080e+00, max vLW: 1.8567e+00
# For vPDE, min vLW: 1.0773e+00, max vLW: 1.4956e+00
# Iter 32000, Total: 4.9838e-04
# IC: 2.5590e-04, PBC: 4.9328e-05, PDE: 1.9315e-04
# For uIC,  min uLW: 1.7588e+00, max uLW: 3.7625e+00
# For uBC,  min uLW: 1.5711e+00, max uLW: 1.7947e+00
# For uPDE, min uLW: 1.1491e+00, max uLW: 5.5916e+00
# For vIC,  min vLW: 1.8554e+00, max vLW: 3.9173e+00
# For vBC,  min vLW: 1.7081e+00, max vLW: 1.8570e+00
# For vPDE, min vLW: 1.0773e+00, max vLW: 1.4960e+00
# Iter 33000, Total: 4.5468e-04
# IC: 2.3702e-04, PBC: 3.8027e-05, PDE: 1.7964e-04
# For uIC,  min uLW: 1.7599e+00, max uLW: 3.7625e+00
# For uBC,  min uLW: 1.5714e+00, max uLW: 1.7949e+00
# For uPDE, min uLW: 1.1500e+00, max uLW: 5.5918e+00
# For vIC,  min vLW: 1.8580e+00, max vLW: 3.9175e+00
# For vBC,  min vLW: 1.7084e+00, max vLW: 1.8572e+00
# For vPDE, min vLW: 1.0773e+00, max vLW: 1.4963e+00
# Iter 34000, Total: 4.1420e-04
# IC: 2.2176e-04, PBC: 2.8603e-05, PDE: 1.6384e-04
# For uIC,  min uLW: 1.7618e+00, max uLW: 3.7625e+00
# For uBC,  min uLW: 1.5718e+00, max uLW: 1.7950e+00
# For uPDE, min uLW: 1.1501e+00, max uLW: 5.5918e+00
# For vIC,  min vLW: 1.8617e+00, max vLW: 3.9178e+00
# For vBC,  min vLW: 1.7088e+00, max vLW: 1.8574e+00
# For vPDE, min vLW: 1.0773e+00, max vLW: 1.4966e+00
# Iter 35000, Total: 3.7249e-04
# IC: 2.0718e-04, PBC: 2.1097e-05, PDE: 1.4421e-04
# For uIC,  min uLW: 1.7650e+00, max uLW: 3.7625e+00
# For uBC,  min uLW: 1.5721e+00, max uLW: 1.7951e+00
# For uPDE, min uLW: 1.1502e+00, max uLW: 5.5922e+00
# For vIC,  min vLW: 1.8670e+00, max vLW: 3.9183e+00
# For vBC,  min vLW: 1.7089e+00, max vLW: 1.8577e+00
# For vPDE, min vLW: 1.0773e+00, max vLW: 1.4968e+00
# Iter 36000, Total: 3.2903e-04
# IC: 1.9242e-04, PBC: 1.5370e-05, PDE: 1.2124e-04
# For uIC,  min uLW: 1.7702e+00, max uLW: 3.7625e+00
# For uBC,  min uLW: 1.5726e+00, max uLW: 1.7951e+00
# For uPDE, min uLW: 1.1505e+00, max uLW: 5.5926e+00
# For vIC,  min vLW: 1.8740e+00, max vLW: 3.9191e+00
# For vBC,  min vLW: 1.7089e+00, max vLW: 1.8580e+00
# For vPDE, min vLW: 1.0773e+00, max vLW: 1.4970e+00
# Iter 37000, Total: 2.8368e-04
# IC: 1.7550e-04, PBC: 1.1903e-05, PDE: 9.6270e-05
# For uIC,  min uLW: 1.7783e+00, max uLW: 3.7625e+00
# For uBC,  min uLW: 1.5732e+00, max uLW: 1.7952e+00
# For uPDE, min uLW: 1.1515e+00, max uLW: 5.5931e+00
# For vIC,  min vLW: 1.8830e+00, max vLW: 3.9203e+00
# For vBC,  min vLW: 1.7089e+00, max vLW: 1.8584e+00
# For vPDE, min vLW: 1.0773e+00, max vLW: 1.4973e+00
# Iter 38000, Total: 2.4134e-04
# IC: 1.5657e-04, PBC: 9.6929e-06, PDE: 7.5075e-05
# For uIC,  min uLW: 1.7893e+00, max uLW: 3.7625e+00
# For uBC,  min uLW: 1.5738e+00, max uLW: 1.7957e+00
# For uPDE, min uLW: 1.1530e+00, max uLW: 5.5936e+00
# For vIC,  min vLW: 1.8932e+00, max vLW: 3.9215e+00
# For vBC,  min vLW: 1.7089e+00, max vLW: 1.8590e+00
# For vPDE, min vLW: 1.0774e+00, max vLW: 1.4977e+00
# Iter 39000, Total: 2.0103e-04
# IC: 1.3359e-04, PBC: 6.6025e-06, PDE: 6.0842e-05
# For uIC,  min uLW: 1.8025e+00, max uLW: 3.7627e+00
# For uBC,  min uLW: 1.5743e+00, max uLW: 1.7962e+00
# For uPDE, min uLW: 1.1544e+00, max uLW: 5.5941e+00
# For vIC,  min vLW: 1.9048e+00, max vLW: 3.9226e+00
# For vBC,  min vLW: 1.7089e+00, max vLW: 1.8594e+00
# For vPDE, min vLW: 1.0775e+00, max vLW: 1.4982e+00
# Iter 40000, Total: 1.6257e-04
# IC: 1.0713e-04, PBC: 5.5375e-06, PDE: 4.9908e-05
# For uIC,  min uLW: 1.8173e+00, max uLW: 3.7632e+00
# For uBC,  min uLW: 1.5746e+00, max uLW: 1.7971e+00
# For uPDE, min uLW: 1.1557e+00, max uLW: 5.5946e+00
# For vIC,  min vLW: 1.9167e+00, max vLW: 3.9235e+00
# For vBC,  min vLW: 1.7091e+00, max vLW: 1.8598e+00
# For vPDE, min vLW: 1.0776e+00, max vLW: 1.4987e+00
# Iter 41000, Total: 1.2741e-04
# IC: 8.1715e-05, PBC: 4.4373e-06, PDE: 4.1261e-05
# For uIC,  min uLW: 1.8313e+00, max uLW: 3.7640e+00
# For uBC,  min uLW: 1.5747e+00, max uLW: 1.7986e+00
# For uPDE, min uLW: 1.1568e+00, max uLW: 5.5950e+00
# For vIC,  min vLW: 1.9267e+00, max vLW: 3.9240e+00
# For vBC,  min vLW: 1.7092e+00, max vLW: 1.8602e+00
# For vPDE, min vLW: 1.0776e+00, max vLW: 1.4990e+00
# Iter 42000, Total: 9.8245e-05
# IC: 6.1093e-05, PBC: 1.9951e-06, PDE: 3.5157e-05
# For uIC,  min uLW: 1.8418e+00, max uLW: 3.7649e+00
# For uBC,  min uLW: 1.5747e+00, max uLW: 1.7997e+00
# For uPDE, min uLW: 1.1575e+00, max uLW: 5.5955e+00
# For vIC,  min vLW: 1.9333e+00, max vLW: 3.9242e+00
# For vBC,  min vLW: 1.7092e+00, max vLW: 1.8605e+00
# For vPDE, min vLW: 1.0776e+00, max vLW: 1.4993e+00
# Iter 43000, Total: 7.8095e-05
# IC: 4.6517e-05, PBC: 9.8456e-07, PDE: 3.0593e-05
# For uIC,  min uLW: 1.8488e+00, max uLW: 3.7654e+00
# For uBC,  min uLW: 1.5747e+00, max uLW: 1.8000e+00
# For uPDE, min uLW: 1.1579e+00, max uLW: 5.5960e+00
# For vIC,  min vLW: 1.9372e+00, max vLW: 3.9242e+00
# For vBC,  min vLW: 1.7094e+00, max vLW: 1.8606e+00
# For vPDE, min vLW: 1.0776e+00, max vLW: 1.4996e+00
# Iter 44000, Total: 2.9572e-03
# IC: 1.6545e-03, PBC: 4.5564e-04, PDE: 8.4710e-04
# For uIC,  min uLW: 2.3112e+00, max uLW: 4.6982e+00
# For uBC,  min uLW: 1.8469e+00, max uLW: 2.0677e+00
# For uPDE, min uLW: 1.2079e+00, max uLW: 6.4721e+00
# For vIC,  min vLW: 2.2872e+00, max vLW: 4.6935e+00
# For vBC,  min vLW: 1.9794e+00, max vLW: 2.1591e+00
# For vPDE, min vLW: 1.0914e+00, max vLW: 1.6292e+00
# Iter 45000, Total: 2.2313e-03
# IC: 1.1242e-03, PBC: 1.8684e-04, PDE: 9.2021e-04
# For uIC,  min uLW: 2.3115e+00, max uLW: 4.6987e+00
# For uBC,  min uLW: 1.8469e+00, max uLW: 2.0677e+00
# For uPDE, min uLW: 1.2081e+00, max uLW: 6.6277e+00
# For vIC,  min vLW: 2.2894e+00, max vLW: 4.6935e+00
# For vBC,  min vLW: 1.9803e+00, max vLW: 2.1591e+00
# For vPDE, min vLW: 1.0922e+00, max vLW: 1.7258e+00
# Iter 46000, Total: 1.9743e-03
# IC: 8.8128e-04, PBC: 1.2591e-04, PDE: 9.6707e-04
# For uIC,  min uLW: 2.3123e+00, max uLW: 4.6992e+00
# For uBC,  min uLW: 1.8470e+00, max uLW: 2.0677e+00
# For uPDE, min uLW: 1.2082e+00, max uLW: 6.7635e+00
# For vIC,  min vLW: 2.2919e+00, max vLW: 4.6936e+00
# For vBC,  min vLW: 1.9806e+00, max vLW: 2.1591e+00
# For vPDE, min vLW: 1.0927e+00, max vLW: 1.8423e+00
# Iter 47000, Total: 1.7890e-03
# IC: 7.0642e-04, PBC: 1.0970e-04, PDE: 9.7284e-04
# For uIC,  min uLW: 2.3132e+00, max uLW: 4.6994e+00
# For uBC,  min uLW: 1.8472e+00, max uLW: 2.0677e+00
# For uPDE, min uLW: 1.2083e+00, max uLW: 6.8815e+00
# For vIC,  min vLW: 2.2946e+00, max vLW: 4.6941e+00
# For vBC,  min vLW: 1.9809e+00, max vLW: 2.1591e+00
# For vPDE, min vLW: 1.0934e+00, max vLW: 1.9352e+00
# Iter 48000, Total: 1.5852e-03
# IC: 5.7310e-04, PBC: 9.6344e-05, PDE: 9.1575e-04
# For uIC,  min uLW: 2.3142e+00, max uLW: 4.6994e+00
# For uBC,  min uLW: 1.8475e+00, max uLW: 2.0677e+00
# For uPDE, min uLW: 1.2094e+00, max uLW: 6.9734e+00
# For vIC,  min vLW: 2.2975e+00, max vLW: 4.6946e+00
# For vBC,  min vLW: 1.9810e+00, max vLW: 2.1591e+00
# For vPDE, min vLW: 1.0946e+00, max vLW: 2.0058e+00
# Iter 49000, Total: 1.3312e-03
# IC: 4.7015e-04, PBC: 7.5052e-05, PDE: 7.8599e-04
# For uIC,  min uLW: 2.3150e+00, max uLW: 4.6994e+00
# For uBC,  min uLW: 1.8478e+00, max uLW: 2.0678e+00
# For uPDE, min uLW: 1.2123e+00, max uLW: 7.0331e+00
# For vIC,  min vLW: 2.3003e+00, max vLW: 4.6951e+00
# For vBC,  min vLW: 1.9810e+00, max vLW: 2.1591e+00
# For vPDE, min vLW: 1.0954e+00, max vLW: 2.0551e+00
# Iter 50000, Total: 1.0721e-03
# IC: 3.9314e-04, PBC: 4.7725e-05, PDE: 6.3126e-04
# For uIC,  min uLW: 2.3155e+00, max uLW: 4.6994e+00
# For uBC,  min uLW: 1.8482e+00, max uLW: 2.0680e+00
# For uPDE, min uLW: 1.2137e+00, max uLW: 7.0638e+00
# For vIC,  min vLW: 2.3028e+00, max vLW: 4.6955e+00
# For vBC,  min vLW: 1.9810e+00, max vLW: 2.1591e+00
# For vPDE, min vLW: 1.0959e+00, max vLW: 2.0861e+00
# Starting with L-BFGS
# Iter  1000, Total: 1.0528e-03
# IC: 3.8726e-04, PBC: 4.4898e-05, PDE: 6.2066e-04
# Iter  2000, Total: 1.0366e-03
# IC: 3.8367e-04, PBC: 4.2561e-05, PDE: 6.1032e-04
# Iter  3000, Total: 1.0218e-03
# IC: 3.8032e-04, PBC: 4.0705e-05, PDE: 6.0076e-04
# Iter  4000, Total: 1.0083e-03
# IC: 3.7709e-04, PBC: 3.9258e-05, PDE: 5.9191e-04
# Iter  5000, Total: 9.9575e-04
# IC: 3.7396e-04, PBC: 3.8126e-05, PDE: 5.8366e-04
# Iter  6000, Total: 9.8414e-04
# IC: 3.7095e-04, PBC: 3.7237e-05, PDE: 5.7596e-04
# Iter  7000, Total: 9.7339e-04
# IC: 3.6808e-04, PBC: 3.6525e-05, PDE: 5.6878e-04
# Iter  8000, Total: 9.6339e-04
# IC: 3.6534e-04, PBC: 3.5941e-05, PDE: 5.6210e-04
# Iter  9000, Total: 9.5377e-04
# IC: 3.6267e-04, PBC: 3.5421e-05, PDE: 5.5568e-04
# Iter 10000, Total: 9.4447e-04
# IC: 3.6006e-04, PBC: 3.4935e-05, PDE: 5.4948e-04
# Iter 11000, Total: 9.3557e-04
# IC: 3.5756e-04, PBC: 3.4464e-05, PDE: 5.4355e-04
# Iter 12000, Total: 9.2717e-04
# IC: 3.5520e-04, PBC: 3.4003e-05, PDE: 5.3796e-04
# Iter 13000, Total: 9.1909e-04
# IC: 3.5294e-04, PBC: 3.3530e-05, PDE: 5.3262e-04
# Iter 14000, Total: 9.1124e-04
# IC: 3.5076e-04, PBC: 3.3037e-05, PDE: 5.2744e-04
# Iter 15000, Total: 9.0370e-04
# IC: 3.4869e-04, PBC: 3.2523e-05, PDE: 5.2249e-04
# Iter 16000, Total: 8.9620e-04
# IC: 3.4666e-04, PBC: 3.1971e-05, PDE: 5.1757e-04
# Iter 17000, Total: 8.8911e-04
# IC: 3.4476e-04, PBC: 3.1410e-05, PDE: 5.1294e-04
# Iter 18000, Total: 8.8206e-04
# IC: 3.4291e-04, PBC: 3.0813e-05, PDE: 5.0834e-04
# Iter 19000, Total: 8.7530e-04
# IC: 3.4117e-04, PBC: 3.0204e-05, PDE: 5.0392e-04
# Iter 20000, Total: 8.6874e-04
# IC: 3.3951e-04, PBC: 2.9581e-05, PDE: 4.9965e-04
# Iter 21000, Total: 8.6237e-04
# IC: 3.3793e-04, PBC: 2.8946e-05, PDE: 4.9550e-04
# Iter 22000, Total: 8.5610e-04
# IC: 3.3641e-04, PBC: 2.8292e-05, PDE: 4.9140e-04
# Iter 23000, Total: 8.4997e-04
# IC: 3.3495e-04, PBC: 2.7629e-05, PDE: 4.8740e-04
# Iter 24000, Total: 8.4403e-04
# IC: 3.3356e-04, PBC: 2.6967e-05, PDE: 4.8350e-04
# Iter 25000, Total: 8.3821e-04
# IC: 3.3223e-04, PBC: 2.6304e-05, PDE: 4.7967e-04
# Iter 26000, Total: 8.3263e-04
# IC: 3.3098e-04, PBC: 2.5654e-05, PDE: 4.7599e-04
# Iter 27000, Total: 8.2709e-04
# IC: 3.2976e-04, PBC: 2.5003e-05, PDE: 4.7232e-04
# Iter 28000, Total: 8.2174e-04
# IC: 3.2860e-04, PBC: 2.4366e-05, PDE: 4.6877e-04
# Iter 29000, Total: 8.1652e-04
# IC: 3.2750e-04, PBC: 2.3744e-05, PDE: 4.6528e-04
# Iter 30000, Total: 8.1148e-04
# IC: 3.2644e-04, PBC: 2.3140e-05, PDE: 4.6189e-04
# Iter 31000, Total: 8.0666e-04
# IC: 3.2545e-04, PBC: 2.2569e-05, PDE: 4.5864e-04
# Iter 32000, Total: 8.0194e-04
# IC: 3.2450e-04, PBC: 2.2011e-05, PDE: 4.5543e-04
# Iter 33000, Total: 7.9735e-04
# IC: 3.2358e-04, PBC: 2.1477e-05, PDE: 4.5229e-04
# Iter 34000, Total: 7.9283e-04
# IC: 3.2269e-04, PBC: 2.0959e-05, PDE: 4.4918e-04
# Iter 35000, Total: 7.8846e-04
# IC: 3.2184e-04, PBC: 2.0468e-05, PDE: 4.4615e-04
# Iter 36000, Total: 7.8418e-04
# IC: 3.2103e-04, PBC: 2.0000e-05, PDE: 4.4315e-04
# Iter 37000, Total: 7.8007e-04
# IC: 3.2025e-04, PBC: 1.9563e-05, PDE: 4.4026e-04
# Iter 38000, Total: 7.7606e-04
# IC: 3.1951e-04, PBC: 1.9148e-05, PDE: 4.3741e-04
# Iter 39000, Total: 7.7226e-04
# IC: 3.1880e-04, PBC: 1.8771e-05, PDE: 4.3468e-04
# Iter 40000, Total: 7.6848e-04
# IC: 3.1811e-04, PBC: 1.8413e-05, PDE: 4.3195e-04
# Iter 41000, Total: 7.6489e-04
# IC: 3.1746e-04, PBC: 1.8087e-05, PDE: 4.2934e-04
# Iter 42000, Total: 7.6135e-04
# IC: 3.1683e-04, PBC: 1.7778e-05, PDE: 4.2675e-04
# Iter 43000, Total: 7.5793e-04
# IC: 3.1622e-04, PBC: 1.7496e-05, PDE: 4.2421e-04
# Iter 44000, Total: 7.5461e-04
# IC: 3.1564e-04, PBC: 1.7238e-05, PDE: 4.2173e-04
# Iter 45000, Total: 7.5141e-04
# IC: 3.1508e-04, PBC: 1.7003e-05, PDE: 4.1933e-04
# Iter 46000, Total: 7.4829e-04
# IC: 3.1454e-04, PBC: 1.6789e-05, PDE: 4.1697e-04
# Iter 47000, Total: 7.4523e-04
# IC: 3.1401e-04, PBC: 1.6595e-05, PDE: 4.1463e-04
# Iter 48000, Total: 7.4233e-04
# IC: 3.1352e-04, PBC: 1.6422e-05, PDE: 4.1239e-04
# Iter 49000, Total: 7.3950e-04
# IC: 3.1304e-04, PBC: 1.6265e-05, PDE: 4.1020e-04
# Iter 50000, Total: 7.3675e-04
# IC: 3.1257e-04, PBC: 1.6130e-05, PDE: 4.0805e-04

# %%
t = np.linspace(tlo, thi, 201)
x = np.linspace(xlo, xhi, 1001)
T, X = np.meshgrid(t, x)
pts_flat = np.hstack((T.flatten()[:, None], X.flatten()[:, None]))
u_pred, v_pred = model.predict(pts_flat)           
u_pred = griddata(pts_flat, u_pred.flatten(), (T, X), method='cubic')
v_pred = griddata(pts_flat, v_pred.flatten(), (T, X), method='cubic')

# %% [markdown]
# ## Visualizations

# %%
data = scipy.io.loadmat('/Users/abraham/Desktop/PINN/New_Data/GS_1D_t20.mat')
t = data['t'].flatten()[:,None]
x2 = data['x'].flatten()[:,None]
u_sol = np.real(data['u_sol']).T
v_sol = np.real(data['v_sol']).T

# %%
fig = plt.figure(figsize=(11, 5))
ax = fig.add_subplot(1, 1, 1)
#
ax.plot(ptsPDE[:, 0], ptsPDE[:, 1], 
    'rd', label = 'PDE Data (%d points)' % (ptsPDE.shape[0]), 
    markersize = 4,  # marker size doubled
    clip_on = False,
    alpha=1.0
)

ax.plot(ptsIC[:, 0], ptsIC[:, 1], 
    'bd', label = 'IC Data (%d points)' % (ptsIC.shape[0]), 
    markersize = 4,  # marker size doubled
    clip_on = False,
    alpha=1.0
)


ax.plot(ptsBC[:, 0], ptsBC[:, 1], 
    'gd', label = 'BC Data (%d points)' % (ptsBC.shape[0]), 
    markersize = 4,  # marker size doubled
    clip_on = False,
    alpha=1.0
)

ax.set_xlabel('$t$', size=15)
ax.set_ylabel('$x$', size=15)
ax.legend(
    loc='upper center', 
    bbox_to_anchor=(0.9, -0.05), 
    ncol=5, 
    frameon=False, 
    prop={'size': 15}
)
ax.legend()
ax.set_title('Points', fontsize = 15) # font size doubled
ax.tick_params(labelsize=12)
#
plt.show()

# %%
####### Row 1: u(t,x) slices ################## 

""" The aesthetic setting has changed. """

fig = plt.figure(figsize=(18, 6))
#
ax = plt.subplot(1, 3, 1)
ax.plot(x2, u_sol[0,:], 'bo-', linewidth = 2, label = 'Exact')       
ax.plot(x, u_pred[:, 0], 'rx--', linewidth = 2, label = 'u')
ax.set_xlabel('$x$')
ax.set_ylabel('$u(t,x)$')    
ax.set_title('$t = %.1f$' %(t[0]), fontsize = 24)



plt.locator_params(axis = 'y', nbins = 5)
plt.locator_params(axis = 'x', nbins = 5)
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(24)

ax = plt.subplot(1, 3, 2)
ax.plot(x2,u_sol[100,:], 'b-', linewidth = 2, label = 'Exact')       
ax.plot(x, u_pred[:, 100], 'rx--', linewidth = 2, label = 'u')
ax.set_xlabel('$x$')




ax.set_title('$t = %.1f$' %(t[100]), fontsize = 24)
ax.legend(
    loc='upper center', 
    bbox_to_anchor=(0.5, -0.15), 
    ncol=5, 
    frameon=False, 
    prop={'size': 24}
)
plt.locator_params(axis = 'y', nbins = 5)
plt.locator_params(axis = 'x', nbins = 5)
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(24)

ax = plt.subplot(1, 3, 3)
ax.plot(x2,u_sol[200,:], 'b-', linewidth = 2, label = 'Exact')       
ax.plot(x, u_pred[:, 200], 'rx--', linewidth = 2, label = 'u')
ax.set_xlabel('$x$')



ax.set_title('$t = %.1f$' %(t[200]), fontsize = 24)
plt.locator_params(axis = 'y', nbins = 5)
plt.locator_params(axis = 'x', nbins = 5)
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(24)

plt.show()
fig.savefig('GSu_1D_BL+SA.png',format='png')

# %%
fig = plt.figure(figsize=(18, 6))
#
ax = plt.subplot(1, 3, 1)
ax.plot(x2, v_sol[0,:], 'bo-', linewidth = 2, label = 'Exact')       
ax.plot(x, v_pred[:, 0], 'rx--', linewidth = 2, label = 'u')
ax.set_xlabel('$x$')
ax.set_ylabel('$u(t,x)$')    
ax.set_title('$t = %.1f$' %(t[0]), fontsize = 24)



plt.locator_params(axis = 'y', nbins = 5)
plt.locator_params(axis = 'x', nbins = 5)
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(24)

ax = plt.subplot(1, 3, 2)
ax.plot(x2,v_sol[100,:], 'b-', linewidth = 2, label = 'Exact')       
ax.plot(x, v_pred[:, 100], 'rx--', linewidth = 2, label = 'u')
ax.set_xlabel('$x$')




ax.set_title('$t = %.1f$' %(t[100]), fontsize = 24)
ax.legend(
    loc='upper center', 
    bbox_to_anchor=(0.5, -0.15), 
    ncol=5, 
    frameon=False, 
    prop={'size': 24}
)
plt.locator_params(axis = 'y', nbins = 5)
plt.locator_params(axis = 'x', nbins = 5)
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(24)

ax = plt.subplot(1, 3, 3)
ax.plot(x2,v_sol[200,:], 'b-', linewidth = 2, label = 'Exact')       
ax.plot(x, v_pred[:, 200], 'rx--', linewidth = 2, label = 'u')
ax.set_xlabel('$x$')



ax.set_title('$t = %.1f$' %(t[200]), fontsize = 24)
plt.locator_params(axis = 'y', nbins = 5)
plt.locator_params(axis = 'x', nbins = 5)
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(24)

plt.show()
fig.savefig('GSv_1D_BL+SA.png',format='png')

# %%
def relative_error_l2(pred,exact):
    error_l2 = np.sqrt(np.sum(np.power(pred - exact,2)))
    relative = error_l2/np.sqrt(np.sum(np.power(exact,2)))
    return relative
def relative_error_l1(pred,exact):
    error_l1 = np.sum(np.abs(pred-exact))
    relative = error_l1/np.sum(np.abs(exact))
    return relative
def relative_error_linf(pred,exact):
    error_linf = np.max(np.abs(pred-exact))
    relative = error_linf/np.max(np.abs(exact))
    return relative

# %%
print(f'l2: {relative_error_l2(u_pred.T,u_sol)}')
print(f'l1: {relative_error_l1(u_pred.T,u_sol)}')
print(f'linf: {relative_error_linf(u_pred.T,u_sol)}')
# Out:
# l2: 0.11543463611515321
# l1: 0.0754467799337355
# linf: 0.27769613319673925

# %%
print(f'l2: {relative_error_l2(v_pred.T,v_sol)}')
print(f'l1: {relative_error_l1(v_pred.T,v_sol)}')
print(f'linf: {relative_error_linf(u_pred.T,v_sol)}')
# Out:
# l2: 0.26230389788472247
# l1: 0.27205580328885404
# linf: 2.890471513859044

# %%
fig = plt.figure(figsize=(24, 6))

ax = plt.subplot(1, 3, 1)
h = ax.imshow(u_sol.T, interpolation='nearest', cmap='rainbow', 
              extent=[tlo, thi, x.min(), x.max()], 
              origin='lower', aspect='auto')
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.10)
cbar = fig.colorbar(h, cax=cax)
cbar.ax.tick_params(labelsize=24) 







ax.set_xlabel('$t$', size=24)
ax.set_ylabel('$x$', size=24)

ax.set_title('$GS: u_{exact}(t,x)$', fontsize = 24) # font size doubled
ax.tick_params(labelsize=24)

ax = plt.subplot(1, 3, 2)
h = ax.imshow(u_pred, interpolation='nearest', cmap='rainbow', 
              extent=[tlo, thi, x.min(), x.max()], 
              origin='lower', aspect='auto')
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.10)
cbar = fig.colorbar(h, cax=cax)
cbar.ax.tick_params(labelsize=24) 




ax.set_xlabel('$t$', size=24)


ax.set_title('$GS: u_{pred}(t,x)$', fontsize = 24) # font size doubled
ax.tick_params(labelsize=24)

ax = plt.subplot(1, 3, 3)
h = ax.imshow(np.abs(u_pred-u_sol.T), interpolation='nearest', cmap='rainbow', 
              extent=[tlo, thi, x.min(), x.max()], 
              origin='lower', aspect='auto')
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.10)
cbar = fig.colorbar(h, cax=cax)
cbar.ax.tick_params(labelsize=24) 




ax.set_xlabel('$t$', size=24)

ax.set_title('$GS(Error): u(t,x)$', fontsize = 24) # font size doubled
ax.tick_params(labelsize=24)


plt.show()
fig.savefig('GS3u_1D_BL+SA.png',format='png')

# %%
fig = plt.figure(figsize=(24, 6))

ax = plt.subplot(1, 3, 1)
h = ax.imshow(v_sol.T, interpolation='nearest', cmap='rainbow', 
              extent=[tlo, thi, x.min(), x.max()], 
              origin='lower', aspect='auto')
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.10)
cbar = fig.colorbar(h, cax=cax)
cbar.ax.tick_params(labelsize=24) 







ax.set_xlabel('$t$', size=24)
ax.set_ylabel('$x$', size=24)

ax.set_title('$GS: v_{exact}(t,x)$', fontsize = 24) # font size doubled
ax.tick_params(labelsize=24)

ax = plt.subplot(1, 3, 2)
h = ax.imshow(u_pred, interpolation='nearest', cmap='rainbow', 
              extent=[tlo, thi, x.min(), x.max()], 
              origin='lower', aspect='auto')
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.10)
cbar = fig.colorbar(h, cax=cax)
cbar.ax.tick_params(labelsize=24) 




ax.set_xlabel('$t$', size=24)


ax.set_title('$GS: v_{pred}(t,x)$', fontsize = 24) # font size doubled
ax.tick_params(labelsize=24)

ax = plt.subplot(1, 3, 3)
h = ax.imshow(np.abs(v_pred-v_sol.T), interpolation='nearest', cmap='rainbow', 
              extent=[tlo, thi, x.min(), x.max()], 
              origin='lower', aspect='auto')
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.10)
cbar = fig.colorbar(h, cax=cax)
cbar.ax.tick_params(labelsize=24) 




ax.set_xlabel('$t$', size=24)


ax.set_title('$GS(Error): v(t,x)$', fontsize = 24) # font size doubled
ax.tick_params(labelsize=24)


plt.show()
fig.savefig('GS3v_1D_BL+SA.png',format='png')
