# %% [markdown]
# # PINN Solution of the Allen-Cahn Equations
#
# This PyTorch code demonstrates the application of physically-informed neural networks (PINN) in the solution of a well-known Allen-Cahn Equations with periodic boundary condition
# \begin{aligned}
#   &u_t = \gamma_1 u_{xx} - \gamma_2 u^3+\gamma_2 u, \quad (t, x) \in [0, T]\times[-L, L]\\
#   &u(0, x) = u_0(x), \quad \forall x \in [-L, L] \\
#   &u(t, -L) = u(t, L), \quad u_x(t, -L) = u_x(t, L), \quad \forall t \in [0, T]
# \end{aligned}
# where $\gamma_1, \gamma_2> 0$ are some parameters, and $[x_{\min}, x_{\max}]$ covers one full period.
#
# Here, we let $u_0(x) = x^2\sin(2\pi x)$.

# %% [markdown]
# ## Libraries and Dependencies

# %%
import torch
import torch.optim
import torch.optim.lr_scheduler as lr_scheduler
from itertools import chain
from collections import OrderedDict
from pyDOE import lhs
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import scipy.io
from scipy.interpolate import griddata
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.gridspec as gridspec
import time
# set the random seed
np.random.seed(1234)

# %%
if torch.backends.mps.is_available():
    device = torch.device('mps')
elif torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
#
print(f"Working on {device}")
# Out:
# Working on mps

# %%
epsilon = 1e-4
gamma = 5
L = 1.0
xlo = -L
xhi = L
period = xhi - xlo
tlo = 0.0
thi = 1.0
pi_ten = torch.tensor(np.pi).float().to(device)
L_ten = torch.tensor(L).float().to(device)
u0 = lambda x: np.power(x, 2.0) * np.cos(np.pi * x)
u0_ten = lambda x: torch.pow(x, 2.0) * torch.cos(pi_ten * x)

# %% [markdown]
# ## Physics-informed Neural Networks

# %%
# the deep neural network
class DNN(torch.nn.Module):
    def __init__(self, layers):
        super(DNN, self).__init__()
        # parameters
        self.depth = len(layers) - 1
        # set up layer order dict
        self.activation = torch.nn.Tanh
        layer_list = list()
        for i in range(self.depth - 1): 
            layer_list.append(
                ('layer_%d' % i, torch.nn.Linear(layers[i], layers[i+1]))
            )
            layer_list.append(('activation_%d' % i, self.activation()))
            
        layer_list.append(
            ('layer_%d' % (self.depth - 1), torch.nn.Linear(layers[-2], layers[-1]))
        )
        layerDict = OrderedDict(layer_list)
        # deploy layers
        self.layers = torch.nn.Sequential(layerDict)
        self.layers[0].weight = torch.load('initial_weights_PBC.pt')
    def forward(self, x):
        out = self.layers(x)
        return out

# %%
class PhysicsInformedNN():
    def __init__(self, period, m, epsilon, gamma, X_IC, u_IC, X_PDE, layers):
        # IC data point
        m_vec = np.expand_dims(np.arange(1, m + 1), axis = 0)
        self.ms = torch.tensor(2.0 * np.pi/period * m_vec).float().to(device)
        layers[0] = int(2 * m + 2)
        self.t_IC = torch.tensor(X_IC[:, 0:1]).float().to(device)
        self.x_IC = torch.tensor(X_IC[:, 1:2]).float().to(device)
        self.u_IC = torch.tensor(u_IC).float().to(device)
        N_IC = X_IC.shape[0]
        self.LW_IC = torch.nn.ParameterList([torch.nn.Parameter(torch.ones(N_IC, 1).float(), requires_grad=True).to(device)])
        
 
        
        self.period = torch.tensor(period).float().to(device)
        # PDE data, gradients will be computed on these points so requires_grad = True
        self.t_PDE = torch.tensor(X_PDE[:, 0:1], requires_grad=True).float().to(device)
        self.x_PDE = torch.tensor(X_PDE[:, 1:2], requires_grad=True).float().to(device)
        N_PDE = X_PDE.shape[0]
        self.LW_PDE = torch.nn.ParameterList([torch.nn.Parameter(torch.ones(N_PDE, 1).float(), requires_grad=True).to(device)])

        # equation related parameters
        self.epsilon = torch.tensor(epsilon).float().to(device)
        self.gamma = torch.tensor(gamma).float().to(device)
        # layers to build Neural Net
        self.layers = layers
        # deep neural networks
        self.dnn = DNN(layers).to(device)    
        # prepare the optimizer
        self.optimizer_Adam = torch.optim.Adam(self.dnn.parameters(), lr = 1e-3)
        self.optimizer_LW_IC = torch.optim.Adam(self.LW_IC.parameters(), lr = 5e-3)
       
        self.optimizer_LW_PDE = torch.optim.Adam(self.LW_PDE.parameters(), lr = 5e-3)
   
        # add a learning rate scheduler
        self.optimizer_LBFGS = torch.optim.LBFGS(
            self.dnn.parameters(), 
            lr=1.0, 
            max_iter=10000, 
            max_eval=5000, 
            history_size=50,
            tolerance_grad=1e-7, 
            tolerance_change=1.0 * np.finfo(float).eps,
            line_search_fn="strong_wolfe"       # can be "strong_wolfe"
        )      
        self.scheduler = lr_scheduler.ExponentialLR(self.optimizer_Adam, gamma=0.99)
        self.iter = 0
    # evaluater neural network, no transformation
    def NN_eval(self, t, x):  
        x_trans = torch.matmul(x, self.ms)
        uNN = self.dnn(torch.cat([t, torch.ones_like(x), torch.cos(x_trans), torch.sin(x_trans)], dim = 1))
        return uNN
    # compute the PDE
    def pde_eval(self, t, x):
        """ The pytorch autograd version of calculating residual """
        u = self.NN_eval(t, x)
        # compute the derivatives for u
        u_t  = torch.autograd.grad(u,   t, grad_outputs = torch.ones_like(u), retain_graph = True, create_graph=True)[0]
        u_x  = torch.autograd.grad(u,   x, grad_outputs = torch.ones_like(u), retain_graph = True, create_graph=True)[0]
        u_xx = torch.autograd.grad(u_x, x, grad_outputs = torch.ones_like(u), retain_graph = True, create_graph=True)[0]
        Eq  = u_t - self.epsilon * u_xx - self.gamma * (u - torch.pow(u, 3.0))       
        return Eq
    # compute the total loss for the second-order optimizer
    def loss_func(self):
        # reset the gradient
        self.optimizer_LBFGS.zero_grad()
        # compute IC loss
        IC_pred = self.NN_eval(self.t_IC, self.x_IC)
        loss_IC = torch.mean(torch.square(self.LW_IC[0] * (IC_pred - self.u_IC)))
       
        # compute PDE loss
        pde_pred = self.pde_eval(self.t_PDE, self.x_PDE)
        loss_PDE = torch.mean(torch.square(self.LW_PDE[0] * pde_pred))    
        # compute the total loss, it can be weighted
        loss = loss_IC  + loss_PDE
        # backward propagation
        loss.backward()
        # increase the iteration counter
        self.iter += 1
        # output
        # output the progress
        if self.iter % 1000 == 0:
            end_time = time.time()
            print('Iter %5d, Total: %10.4e, Time: %.2f secs' % (self.iter, loss.item(), end_time - self.start_time))
            print('IC: %10.4e,  PDE: %10.4e' % (loss_IC.item(),  loss_PDE.item()))
            self.start_time = end_time
        return loss
    #
    def train(self, nIter):
        # start the timer
        start_time = time.time()        
        # start the training with Adam first
        self.dnn.train()
        print('Starting with Adam')
        for epoch in range(nIter):
            # compute IC loss
            IC_pred = self.NN_eval(self.t_IC, self.x_IC)
            loss_IC = torch.mean(torch.square(self.LW_IC[0] * (IC_pred - self.u_IC)))
            
            # compute PDE loss
            pde_pred = self.pde_eval(self.t_PDE, self.x_PDE)
            loss_PDE = torch.mean(torch.square(self.LW_PDE[0] * pde_pred))   
            # compute the total loss, it can be weighted
            loss = loss_IC +  loss_PDE
            # Backward and optimize
            self.optimizer_Adam.zero_grad()
            self.optimizer_LW_IC.zero_grad()
            
            self.optimizer_LW_PDE.zero_grad()
            loss.backward()
            self.optimizer_Adam.step() 
            self.LW_IC[0].grad.data = -self.LW_IC[0].grad.data
           
            self.LW_PDE[0].grad.data = -self.LW_PDE[0].grad.data
            self.optimizer_LW_IC.step()
         
            self.optimizer_LW_PDE.step()
            # output the progress
            if (epoch + 1) % 1000 == 0:
                end_time = time.time()
                print('Iter %5d, Total: %10.4e, Time: %.2f secs' % (epoch + 1, loss.item(), end_time - start_time))
                print('IC: %10.4e,  PDE: %10.4e' % (loss_IC.item(), loss_PDE.item()))
                print('For IC,  min LW: %10.4e, max LW: %10.4e' %(torch.min(self.LW_IC[0]).item(), torch.max(self.LW_IC[0]).item()))
                print('For PDE, min LW: %10.4e, max LW: %10.4e' %(torch.min(self.LW_PDE[0]).item(), torch.max(self.LW_PDE[0]).item()))
               
                start_time = end_time
                # change the learning rate
                self.scheduler.step()

        self.start_time = time.time()
        self.optimizer_LBFGS.step(self.loss_func)    

        
    def predict(self, X):
        t = torch.tensor(X[:, 0:1], requires_grad=True).float().to(device)
        x = torch.tensor(X[:, 1:2], requires_grad=True).float().to(device)
        self.dnn.eval()
        u = self.NN_eval(t, x)
        u = u.detach().cpu().numpy()
        return u

# %% [markdown]
# ## Training

# %%
layers = [2, 32, 32, 32, 32, 32, 32, 32, 1]
m = 16
ptsIC=np.load('ptsIC.npy')
ptsBC=np.load('ptsBC.npy')
ptsPDE=np.load('random_data.npy')
ptsPDE= np.vstack((ptsPDE,ptsBC))
u_IC=np.load('u_IC.npy')
model = PhysicsInformedNN(period, m, epsilon, gamma, ptsIC, u_IC, ptsPDE, layers)
model.train(50000)
# Out:
# Starting with Adam
# Iter  1000, Total: 6.1918e+00, Time: 48.81 secs
# IC: 5.2688e+00,  PDE: 9.2300e-01
# For IC,  min LW: 4.0475e+00, max LW: 8.3274e+00
# For PDE, min LW: 3.4368e+00, max LW: 9.9907e+00
# Iter  2000, Total: 1.6194e+01, Time: 43.74 secs
# IC: 1.3390e+01,  PDE: 2.8033e+00
# For IC,  min LW: 6.2357e+00, max LW: 1.5254e+01
# For PDE, min LW: 6.5861e+00, max LW: 1.8932e+01
# Iter  3000, Total: 1.9525e+01, Time: 43.56 secs
# IC: 1.1258e+01,  PDE: 8.2664e+00
# For IC,  min LW: 6.5452e+00, max LW: 2.1884e+01
# For PDE, min LW: 7.6128e+00, max LW: 2.6355e+01
# Iter  4000, Total: 4.6517e+00, Time: 43.59 secs
# IC: 2.0869e+00,  PDE: 2.5648e+00
# For IC,  min LW: 6.6958e+00, max LW: 2.7829e+01
# For PDE, min LW: 7.8682e+00, max LW: 3.1106e+01
# Iter  5000, Total: 3.3836e+00, Time: 43.65 secs
# IC: 1.6116e+00,  PDE: 1.7720e+00
# For IC,  min LW: 6.8793e+00, max LW: 3.3331e+01
# For PDE, min LW: 8.2809e+00, max LW: 3.6157e+01
# Iter  6000, Total: 3.4291e+00, Time: 43.50 secs
# IC: 1.7593e+00,  PDE: 1.6698e+00
# For IC,  min LW: 7.5689e+00, max LW: 3.9224e+01
# For PDE, min LW: 8.9209e+00, max LW: 3.9087e+01
# Iter  7000, Total: 2.9816e+00, Time: 43.40 secs
# IC: 1.0663e+00,  PDE: 1.9153e+00
# For IC,  min LW: 8.1976e+00, max LW: 4.2862e+01
# For PDE, min LW: 9.1041e+00, max LW: 4.2427e+01
# Iter  8000, Total: 2.0742e+00, Time: 43.08 secs
# IC: 9.2093e-01,  PDE: 1.1533e+00
# For IC,  min LW: 8.3717e+00, max LW: 4.7654e+01
# For PDE, min LW: 9.3703e+00, max LW: 4.3846e+01
# Iter  9000, Total: 2.3267e+00, Time: 42.96 secs
# IC: 8.3607e-01,  PDE: 1.4906e+00
# For IC,  min LW: 8.5990e+00, max LW: 5.1366e+01
# For PDE, min LW: 9.7536e+00, max LW: 4.7198e+01
# Iter 10000, Total: 2.3807e+00, Time: 42.79 secs
# IC: 1.2213e+00,  PDE: 1.1594e+00
# For IC,  min LW: 9.3468e+00, max LW: 5.6054e+01
# For PDE, min LW: 9.9290e+00, max LW: 5.0583e+01
# Iter 11000, Total: 2.6097e+00, Time: 42.92 secs
# IC: 8.7136e-01,  PDE: 1.7384e+00
# For IC,  min LW: 9.8892e+00, max LW: 6.1355e+01
# For PDE, min LW: 1.0062e+01, max LW: 5.3748e+01
# Iter 12000, Total: 2.0201e+00, Time: 42.89 secs
# IC: 1.0120e+00,  PDE: 1.0081e+00
# For IC,  min LW: 1.0439e+01, max LW: 6.6560e+01
# For PDE, min LW: 1.0243e+01, max LW: 5.8216e+01
# Iter 13000, Total: 2.2959e+00, Time: 43.17 secs
# IC: 1.2752e+00,  PDE: 1.0207e+00
# For IC,  min LW: 1.0809e+01, max LW: 7.1604e+01
# For PDE, min LW: 1.0542e+01, max LW: 6.2084e+01
# Iter 14000, Total: 2.2103e+00, Time: 42.88 secs
# IC: 1.2437e+00,  PDE: 9.6660e-01
# For IC,  min LW: 1.1049e+01, max LW: 7.6414e+01
# For PDE, min LW: 1.1168e+01, max LW: 6.6483e+01
# Iter 15000, Total: 2.4782e+00, Time: 43.14 secs
# IC: 1.1548e+00,  PDE: 1.3233e+00
# For IC,  min LW: 1.1476e+01, max LW: 8.1651e+01
# For PDE, min LW: 1.3116e+01, max LW: 7.1283e+01
# Iter 16000, Total: 2.9611e+00, Time: 42.65 secs
# IC: 1.0778e+00,  PDE: 1.8833e+00
# For IC,  min LW: 1.2179e+01, max LW: 8.6752e+01
# For PDE, min LW: 1.8089e+01, max LW: 7.5328e+01
# Iter 17000, Total: 2.3866e+00, Time: 41.13 secs
# IC: 1.3433e+00,  PDE: 1.0432e+00
# For IC,  min LW: 1.3330e+01, max LW: 9.2142e+01
# For PDE, min LW: 2.2796e+01, max LW: 7.8688e+01
# Iter 18000, Total: 4.1995e+00, Time: 40.76 secs
# IC: 1.9306e+00,  PDE: 2.2689e+00
# For IC,  min LW: 1.4864e+01, max LW: 9.7509e+01
# For PDE, min LW: 2.4985e+01, max LW: 8.2104e+01
# Iter 19000, Total: 3.0475e+00, Time: 41.55 secs
# IC: 1.2595e+00,  PDE: 1.7880e+00
# For IC,  min LW: 1.6854e+01, max LW: 1.0282e+02
# For PDE, min LW: 2.7450e+01, max LW: 8.7066e+01
# Iter 20000, Total: 2.4705e+00, Time: 41.36 secs
# IC: 1.3230e+00,  PDE: 1.1475e+00
# For IC,  min LW: 1.8645e+01, max LW: 1.0801e+02
# For PDE, min LW: 2.9469e+01, max LW: 9.1881e+01
# Iter 21000, Total: 2.5328e+00, Time: 41.44 secs
# IC: 1.3270e+00,  PDE: 1.2058e+00
# For IC,  min LW: 2.0442e+01, max LW: 1.1299e+02
# For PDE, min LW: 3.1586e+01, max LW: 9.6971e+01
# Iter 22000, Total: 3.5270e+00, Time: 40.91 secs
# IC: 1.7806e+00,  PDE: 1.7463e+00
# For IC,  min LW: 2.1863e+01, max LW: 1.1773e+02
# For PDE, min LW: 3.3091e+01, max LW: 1.0181e+02
# Iter 23000, Total: 4.1230e+00, Time: 40.74 secs
# IC: 1.2059e+00,  PDE: 2.9171e+00
# For IC,  min LW: 2.3911e+01, max LW: 1.2230e+02
# For PDE, min LW: 3.5136e+01, max LW: 1.0646e+02
# Iter 24000, Total: 3.5911e+00, Time: 41.28 secs
# IC: 1.1934e+00,  PDE: 2.3976e+00
# For IC,  min LW: 2.5704e+01, max LW: 1.2686e+02
# For PDE, min LW: 3.6541e+01, max LW: 1.1101e+02
# Iter 25000, Total: 5.7154e+00, Time: 40.60 secs
# IC: 2.1288e+00,  PDE: 3.5866e+00
# For IC,  min LW: 2.7998e+01, max LW: 1.3149e+02
# For PDE, min LW: 3.8087e+01, max LW: 1.1545e+02
# Iter 26000, Total: 3.0900e+00, Time: 41.09 secs
# IC: 1.6948e+00,  PDE: 1.3953e+00
# For IC,  min LW: 2.9737e+01, max LW: 1.3617e+02
# For PDE, min LW: 3.9719e+01, max LW: 1.1977e+02
# Iter 27000, Total: 3.2007e+00, Time: 40.91 secs
# IC: 1.5826e+00,  PDE: 1.6181e+00
# For IC,  min LW: 3.1611e+01, max LW: 1.4082e+02
# For PDE, min LW: 4.1234e+01, max LW: 1.2387e+02
# Iter 28000, Total: 3.9234e+00, Time: 41.26 secs
# IC: 1.4016e+00,  PDE: 2.5218e+00
# For IC,  min LW: 3.3832e+01, max LW: 1.4588e+02
# For PDE, min LW: 4.3075e+01, max LW: 1.2864e+02
# Iter 29000, Total: 7.0655e+00, Time: 41.10 secs
# IC: 2.6186e+00,  PDE: 4.4470e+00
# For IC,  min LW: 3.5059e+01, max LW: 1.5065e+02
# For PDE, min LW: 4.4633e+01, max LW: 1.3405e+02
# Iter 30000, Total: 4.7939e+00, Time: 41.04 secs
# IC: 1.6574e+00,  PDE: 3.1366e+00
# For IC,  min LW: 3.6139e+01, max LW: 1.5441e+02
# For PDE, min LW: 4.6160e+01, max LW: 1.3822e+02
# Iter 31000, Total: 2.3600e+00, Time: 41.05 secs
# IC: 5.6040e-01,  PDE: 1.7996e+00
# For IC,  min LW: 3.8222e+01, max LW: 1.5798e+02
# For PDE, min LW: 4.7882e+01, max LW: 1.4018e+02
# Iter 32000, Total: 4.8778e+00, Time: 41.09 secs
# IC: 1.3158e+00,  PDE: 3.5620e+00
# For IC,  min LW: 3.9636e+01, max LW: 1.6107e+02
# For PDE, min LW: 4.9791e+01, max LW: 1.4174e+02
# Iter 33000, Total: 1.9255e+00, Time: 40.26 secs
# IC: 5.2827e-01,  PDE: 1.3972e+00
# For IC,  min LW: 4.0485e+01, max LW: 1.6374e+02
# For PDE, min LW: 5.1292e+01, max LW: 1.4364e+02
# Iter 34000, Total: 1.2291e+01, Time: 40.49 secs
# IC: 9.0637e-01,  PDE: 1.1385e+01
# For IC,  min LW: 4.1798e+01, max LW: 1.6615e+02
# For PDE, min LW: 5.2684e+01, max LW: 1.4633e+02
# Iter 35000, Total: 3.1149e+00, Time: 40.24 secs
# IC: 5.0992e-01,  PDE: 2.6050e+00
# For IC,  min LW: 4.3174e+01, max LW: 1.6848e+02
# For PDE, min LW: 5.4266e+01, max LW: 1.5004e+02
# Iter 36000, Total: 1.8231e+00, Time: 40.83 secs
# IC: 5.2065e-01,  PDE: 1.3024e+00
# For IC,  min LW: 4.4424e+01, max LW: 1.7088e+02
# For PDE, min LW: 5.6003e+01, max LW: 1.5384e+02
# Iter 37000, Total: 1.7777e+00, Time: 41.23 secs
# IC: 4.8861e-01,  PDE: 1.2891e+00
# For IC,  min LW: 4.5931e+01, max LW: 1.7468e+02
# For PDE, min LW: 5.7899e+01, max LW: 1.5815e+02
# Iter 38000, Total: 1.8143e+00, Time: 41.17 secs
# IC: 5.1652e-01,  PDE: 1.2977e+00
# For IC,  min LW: 4.7495e+01, max LW: 1.7958e+02
# For PDE, min LW: 5.9586e+01, max LW: 1.6251e+02
# Iter 39000, Total: 2.4579e+00, Time: 40.59 secs
# IC: 4.7016e-01,  PDE: 1.9878e+00
# For IC,  min LW: 4.8526e+01, max LW: 1.8446e+02
# For PDE, min LW: 6.1264e+01, max LW: 1.6694e+02
# Iter 40000, Total: 2.2180e+00, Time: 40.95 secs
# IC: 5.0466e-01,  PDE: 1.7133e+00
# For IC,  min LW: 4.9944e+01, max LW: 1.8934e+02
# For PDE, min LW: 6.2980e+01, max LW: 1.7135e+02
# Iter 41000, Total: 3.3880e+00, Time: 40.79 secs
# IC: 8.9115e-01,  PDE: 2.4968e+00
# For IC,  min LW: 5.0583e+01, max LW: 1.9420e+02
# For PDE, min LW: 6.4292e+01, max LW: 1.7568e+02
# Iter 42000, Total: 1.8116e+00, Time: 41.03 secs
# IC: 5.2358e-01,  PDE: 1.2880e+00
# For IC,  min LW: 5.1618e+01, max LW: 1.9906e+02
# For PDE, min LW: 6.5409e+01, max LW: 1.7999e+02
# Iter 43000, Total: 2.5936e+00, Time: 40.85 secs
# IC: 7.4601e-01,  PDE: 1.8476e+00
# For IC,  min LW: 5.3038e+01, max LW: 2.0391e+02
# For PDE, min LW: 6.6949e+01, max LW: 1.8429e+02
# Iter 44000, Total: 3.9354e+00, Time: 40.68 secs
# IC: 9.4592e-01,  PDE: 2.9895e+00
# For IC,  min LW: 5.3615e+01, max LW: 2.0874e+02
# For PDE, min LW: 6.7366e+01, max LW: 1.8883e+02
# Iter 45000, Total: 4.2430e+00, Time: 41.14 secs
# IC: 8.9301e-01,  PDE: 3.3500e+00
# For IC,  min LW: 5.4714e+01, max LW: 2.1354e+02
# For PDE, min LW: 6.8325e+01, max LW: 1.9343e+02
# Iter 46000, Total: 2.0351e+00, Time: 40.57 secs
# IC: 6.5934e-01,  PDE: 1.3758e+00
# For IC,  min LW: 5.5944e+01, max LW: 2.1832e+02
# For PDE, min LW: 6.9403e+01, max LW: 1.9799e+02
# Iter 47000, Total: 3.5215e+00, Time: 41.25 secs
# IC: 7.2300e-01,  PDE: 2.7985e+00
# For IC,  min LW: 5.7382e+01, max LW: 2.2306e+02
# For PDE, min LW: 7.0424e+01, max LW: 2.0253e+02
# Iter 48000, Total: 2.0299e+00, Time: 41.14 secs
# IC: 6.3403e-01,  PDE: 1.3959e+00
# For IC,  min LW: 5.9339e+01, max LW: 2.2775e+02
# For PDE, min LW: 7.1857e+01, max LW: 2.0702e+02
# Iter 49000, Total: 1.9387e+00, Time: 41.11 secs
# IC: 5.5716e-01,  PDE: 1.3816e+00
# For IC,  min LW: 6.1156e+01, max LW: 2.3239e+02
# For PDE, min LW: 7.3916e+01, max LW: 2.1151e+02
# Iter 50000, Total: 5.2411e+00, Time: 40.45 secs
# IC: 1.0220e+00,  PDE: 4.2190e+00
# For IC,  min LW: 6.3119e+01, max LW: 2.3698e+02
# For PDE, min LW: 7.6198e+01, max LW: 2.1598e+02
# Iter  1000, Total: 9.6457e-01, Time: 85.84 secs
# IC: 2.8367e-01,  PDE: 6.8090e-01
# Iter  2000, Total: 5.8393e-01, Time: 76.12 secs
# IC: 1.6958e-01,  PDE: 4.1435e-01
# Iter  3000, Total: 4.1714e-01, Time: 76.44 secs
# IC: 1.3533e-01,  PDE: 2.8181e-01
# Iter  4000, Total: 3.3021e-01, Time: 75.49 secs
# IC: 1.1951e-01,  PDE: 2.1070e-01
# Iter  5000, Total: 2.8098e-01, Time: 75.24 secs
# IC: 1.1473e-01,  PDE: 1.6625e-01

# %%
t = np.linspace(tlo, thi, 101)
x = np.linspace(xlo, xhi, 201)
T, X = np.meshgrid(t, x)
pts_flat = np.hstack((T.flatten()[:, None], X.flatten()[:, None]))
u_pred = model.predict(pts_flat)           
u_pred = griddata(pts_flat, u_pred.flatten(), (T, X), method='cubic')

# %% [markdown]
# ## Visualizations

# %%
data = scipy.io.loadmat('/Users/abraham/Desktop/PINN/New_Data/AC_1D_case1_cos.mat')
t = data['t'].flatten()[:,None]
x2 = data['x'].flatten()[:,None]
exact_sol = np.real(data['exact_sol']).T

# %%
fig = plt.figure(figsize=(11, 5))
ax = fig.add_subplot(1, 1, 1)
#
ax.plot(ptsPDE[:, 0], ptsPDE[:, 1], 
    'rd', label = 'PDE Data (%d points)' % (ptsPDE.shape[0]), 
    markersize = 4,  # marker size doubled
    clip_on = False,
    alpha=1.0
)

ax.plot(ptsIC[:, 0], ptsIC[:, 1], 
    'bd', label = 'IC Data (%d points)' % (ptsIC.shape[0]), 
    markersize = 4,  # marker size doubled
    clip_on = False,
    alpha=1.0
)


ax.plot(ptsBC[:, 0], ptsBC[:, 1], 
    'gd', label = 'BC Data (%d points)' % (ptsBC.shape[0]), 
    markersize = 4,  # marker size doubled
    clip_on = False,
    alpha=1.0
)

ax.set_xlabel('$t$', size=15)
ax.set_ylabel('$x$', size=15)
ax.legend(
    loc='upper center', 
    bbox_to_anchor=(0.9, -0.05), 
    ncol=5, 
    frameon=False, 
    prop={'size': 15}
)
ax.legend()
ax.set_title('Points', fontsize = 15) # font size doubled
ax.tick_params(labelsize=12)
#
plt.show()

# %%
####### Row 1: u(t,x) slices ################## 

""" The aesthetic setting has changed. """

fig = plt.figure(figsize=(18, 6))
#
ax = plt.subplot(1, 3, 1)
ax.plot(x2, exact_sol[0,:], 'bo-', linewidth = 2, label = 'Exact')       
ax.plot(x, u_pred[:, 0], 'rx--', linewidth = 2, label = 'u')
ax.set_xlabel('$x$')
ax.set_ylabel('$u(t,x)$')    
ax.set_title('$t = %.1f$' %(t[0]), fontsize = 24)


plt.locator_params(axis = 'y', nbins = 5)
plt.locator_params(axis = 'x', nbins = 5)
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(24)

ax = plt.subplot(1, 3, 2)
ax.plot(x,exact_sol[50,:], 'bo-', linewidth = 2, label = 'Exact')       
ax.plot(x, u_pred[:, 50], 'rx--', linewidth = 2, label = 'u')

ax.set_xlabel('x')




ax.set_title('$t = %.1f$' %(t[50]), fontsize = 24)
ax.legend(
    loc='upper center', 
    bbox_to_anchor=(0.5, -0.15), 
    ncol=5, 
    frameon=False, 
    prop={'size': 24}
)
plt.locator_params(axis = 'y', nbins = 5)
plt.locator_params(axis = 'x', nbins = 5)
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(24)

ax = plt.subplot(1, 3, 3)
ax.plot(x,exact_sol[100,:], 'bo-', linewidth = 2, label = 'Exact')       
ax.plot(x, u_pred[:, 100], 'rx--', linewidth = 2, label = 'u')

ax.set_xlabel('$x$')




ax.set_title('$t = %.1f$' %(t[100]), fontsize = 24)
plt.locator_params(axis = 'y', nbins = 5)
plt.locator_params(axis = 'x', nbins = 5)
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(24)

plt.show()
fig.savefig('AC_case1_BL+PBC+SA.png',format='png')

# %%
def relative_error_l2(pred,exact):
    error_l2 = np.sqrt(np.sum(np.power(pred - exact,2)))
    relative = error_l2/np.sqrt(np.sum(np.power(exact,2)))
    return relative
def relative_error_l1(pred,exact):
    error_l1 = np.sum(np.abs(pred-exact))
    relative = error_l1/np.sum(np.abs(exact))
    return relative
def relative_error_linf(pred,exact):
    error_linf = np.max(np.abs(pred-exact))
    relative = error_linf/np.max(np.abs(exact))
    return relative

# %%
print(f'l2: {relative_error_l2(u_pred.T,exact_sol)}')
print(f'l1: {relative_error_l1(u_pred.T,exact_sol)}')
print(f'linf: {relative_error_linf(u_pred.T,exact_sol)}')
# Out:
# l2: 1.0060973644171745
# l1: 0.9983868632413514
# linf: 1.8691727710678314

# %%
fig = plt.figure(figsize=(24, 6))

ax = plt.subplot(1, 3, 1)
h = ax.imshow(exact_sol.T, interpolation='nearest', cmap='rainbow', 
              extent=[tlo, thi, x.min(), x.max()], 
              origin='lower', aspect='auto')
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.10)
cbar = fig.colorbar(h, cax=cax)
cbar.ax.tick_params(labelsize=24) 

cbar.set_ticks([-1,0,1])



ax.set_xlabel('$t$', size=24)
ax.set_ylabel('$x$', size=24)
ax.set_xticks([0 ,0.5 ,1])
ax.set_yticks([-1 ,0 ,1])
ax.set_title('$AC: u_{exact}(t,x)$', fontsize = 24) # font size doubled
ax.tick_params(labelsize=24)

ax = plt.subplot(1, 3, 2)
h = ax.imshow(u_pred, interpolation='nearest', cmap='rainbow', 
              extent=[tlo, thi, x.min(), x.max()], 
              origin='lower', aspect='auto')
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.10)
cbar = fig.colorbar(h, cax=cax)
cbar.ax.tick_params(labelsize=24) 




ax.set_xlabel('$t$', size=24)

ax.set_xticks([0 ,0.5 ,1])
ax.set_yticks([-1 ,0 ,1])
ax.set_title('$AC: u_{pred}(t,x)$', fontsize = 24) # font size doubled
ax.tick_params(labelsize=24)

ax = plt.subplot(1, 3, 3)
h = ax.imshow(np.abs(u_pred-exact_sol.T), interpolation='nearest', cmap='rainbow', 
              extent=[tlo, thi, x.min(), x.max()], 
              origin='lower', aspect='auto')
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.10)
cbar = fig.colorbar(h, cax=cax)
cbar.ax.tick_params(labelsize=24) 

ax.set_xlabel('$t$', size=24)

ax.set_xticks([0 ,0.5 ,1])
ax.set_yticks([-1 ,0 ,1])
ax.set_title('$AC(Error): u(t,x)$', fontsize = 24) # font size doubled
ax.tick_params(labelsize=24)


plt.show()
fig.savefig('AC3_case1_BL+PBC+SA.png',format='png')
